# %% [markdown]
# # Reads in the dataset

# %%
# Imports libraries
import json

# %%
# Declares constants
dataset_filename = "bdd100k_labels_images_train.json"

# %%
# Reads in the declared file
with open(dataset_filename, "r") as read_file:
    dataset = json.load(read_file)

# Gets properties of the dataset
dataset_len = len(dataset)
dataset_keys = dataset[0].keys()

# %% [markdown]
# ## Describes the dataset

# %%
print('Number of Groups: {0}'.format(dataset_len))
# Out:
# Number of Groups: 69863

# %%
print('Number of keys per Group: {0}'.format(len(dataset_keys)))

# Print each key
for key in dataset_keys:
    print('  key: {0}'.format(key))
# Out:
# Number of keys per Group: 4
#   key: name
#   key: attributes
#   key: timestamp
#   key: labels

# %%
import random

sample_index = random.randint(0, dataset_len)
sample = dataset[sample_index]

sample
# Out:
# {'name': '45cee415-3919c3d5.jpg',
#  'attributes': {'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  'timestamp': 10000,
#  'labels': [{'category': 'traffic light',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'red'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 423.868242,
#     'y1': 239.22934,
#     'x2': 459.752644,
#     'y2': 247.030297},
#    'id': 757793},
#   {'category': 'traffic light',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'red'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 494.076855,
#     'y1': 239.22934,
#     'x2': 517.479726,
#     'y2': 250.15068},
#    'id': 757794},
#   {'category': 'traffic light',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'red'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 1076.028249,
#     'y1': 240.789532,
#     'x2': 1099.43112,
#     'y2': 265.752594},
#    'id': 757795},
#   {'category': 'traffic light',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'red'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 1041.704038,
#     'y1': 248.590489,
#     'x2': 1072.907866,
#     'y2': 270.433168},
#    'id': 757796},
#   {'category': 'traffic light',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'red'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 160.195895,
#     'y1': 362.484461,
#     'x2': 171.117233,
#     'y2': 374.965993},
#    'id': 757797},
#   {'category': 'traffic light',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'green'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 804.344659,
#     'y1': 174.64059,
#     'x2': 827.957816,
#     'y2': 212.706085},
#    'id': 757798},
#   {'category': 'traffic light',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'green'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 1026.102124,
#     'y1': 112.853837,
#     'x2': 1054.185569,
#     'y2': 159.659579},
#    'id': 757799},
#   {'category': 'traffic light',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'none'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 1007.379827,
#     'y1': 247.030297,
#     'x2': 1032.34289,
#     'y2': 275.113743},
#    'id': 757800},
#   {'category': 'traffic sign',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'none'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 353.659629,
#     'y1': 231.428383,
#     'x2': 387.98384,
#     'y2': 253.271063},
#    'id': 757801},
#   {'category': 'traffic sign',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'none'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 558.044703,
#     'y1': 193.98379,
#     'x2': 603.290253,
#     'y2': 245.470108},
#    'id': 757802},
#   {'category': 'traffic sign',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'none'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 603.290253,
#     'y1': 197.104172,
#     'x2': 642.295038,
#     'y2': 247.030297},
#    'id': 757803},
#   {'category': 'traffic sign',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'none'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 1079.148632,
#     'y1': 179.942067,
#     'x2': 1113.472843,
#     'y2': 193.98379},
#    'id': 757804},
#   {'category': 'traffic sign',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'none'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 980.856575,
#     'y1': 267.312786,
#     'x2': 1002.699254,
#     'y2': 279.794317},
#    'id': 757805},
#   {'category': 'traffic sign',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'none'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 993.338104,
#     'y1': 298.516614,
#     'x2': 1010.500212,
#     'y2': 326.600059},
#    'id': 757806},
#   {'category': 'traffic sign',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'none'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 567.405851,
#     'y1': 332.840825,
#     'x2': 586.128146,
#     'y2': 354.683502},
#    'id': 757807},
#   {'category': 'traffic sign',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'none'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 529.961257,
#     'y1': 289.155465,
#     'x2': 586.128146,
#     'y2': 325.039868},
#    'id': 757808},
#   {'category': 'traffic sign',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'none'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 523.720492,
#     'y1': 334.401016,
#     'x2': 540.882599,
#     'y2': 357.803887},
#    'id': 757809},
#   {'category': 'traffic sign',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'none'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 68.144602,
#     'y1': 339.081592,
#     'x2': 102.468813,
#     'y2': 374.965994},
#    'id': 757810},
#   {'category': 'car',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'none'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 629.813509,
#     'y1': 279.794317,
#     'x2': 916.888727,
#     'y2': 507.582264},
#    'id': 757811},
#   {'category': 'car',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'none'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 149.274555,
#     'y1': 329.720442,
#     'x2': 529.961257,
#     'y2': 619.916045},
#    'id': 757812},
#   {'category': 'traffic sign',
#    'attributes': {'occluded': False,
#     'truncated': False,
#     'trafficLightColor': 'none'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'box2d': {'x1': 618.726661,
#     'y1': 305.371545,
#     'x2': 636.689693,
#     'y2': 340.299663},
#    'id': 757813},
#   {'category': 'drivable area',
#    'attributes': {'areaType': 'alternative'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[781.607877, 599.374002],
#       [936.697822, 587.08965],
#       [1119.427558, 620.871618],
#       [1280.6437, 633.15597],
#       [1280.6437, 553.307682],
#       [993.51295, 490.350377],
#       [695.617413, 531.810065],
#       [781.607877, 599.374002]],
#      'types': 'LCCCLLLL',
#      'closed': True}],
#    'id': 757814},
#   {'category': 'drivable area',
#    'attributes': {'areaType': 'alternative'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[1280.6437, 464.246129],
#       [933.626734, 424.321985],
#       [922.877926, 464.246129],
#       [1280.6437, 541.02333],
#       [1280.6437, 464.246129]],
#      'types': 'LLLLL',
#      'closed': True}],
#    'id': 757815},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'vertical',
#     'laneStyle': 'dashed',
#     'laneType': 'crosswalk'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[6.394738, 496.231582], [147.078948, 484.721055]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757816},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'vertical',
#     'laneStyle': 'dashed',
#     'laneType': 'crosswalk'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[3.836842, 474.489476], [149.636842, 469.373687]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757817},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'vertical',
#     'laneStyle': 'dashed',
#     'laneType': 'crosswalk'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[525.647372, 459.142108],
#       [635.636845, 454.026318]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757818},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'vertical',
#     'laneStyle': 'dashed',
#     'laneType': 'crosswalk'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[523.089476, 439.957897],
#       [635.636845, 432.284212]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757819},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'vertical',
#     'laneStyle': 'dashed',
#     'laneType': 'crosswalk'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[942.584215, 402.868422],
#       [1003.973688, 414.378951]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757820},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'parallel',
#     'laneStyle': 'solid',
#     'laneType': 'road curb'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[963.047373, 429.726318],
#       [1277.668428, 457.86316]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757821},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'parallel',
#     'laneStyle': 'solid',
#     'laneType': 'single white'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[913.168426, 469.373687],
#       [1280.226322, 546.110528]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757822},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'parallel',
#     'laneStyle': 'solid',
#     'laneType': 'single white'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[610.057898, 479.605265],
#       [745.626321, 593.431582]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757823},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'parallel',
#     'laneStyle': 'solid',
#     'laneType': 'single white'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[617.731582, 474.489476],
#       [778.878952, 595.989477]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757824},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'parallel',
#     'laneStyle': 'solid',
#     'laneType': 'single white'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[80.573685, 494.952635], [0, 520.531582]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757825},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'parallel',
#     'laneStyle': 'solid',
#     'laneType': 'double white'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[147.078948, 571.689478], [26.857895, 643.31053]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757826},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'parallel',
#     'laneStyle': 'solid',
#     'laneType': 'double white'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[164.984212, 593.431582], [98.478948, 638.194741]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757827},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'vertical',
#     'laneStyle': 'solid',
#     'laneType': 'single white'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[530.763161, 479.605265],
#       [635.636845, 473.210529]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757828},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'vertical',
#     'laneStyle': 'solid',
#     'laneType': 'single white'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[530.763161, 474.489476],
#       [635.636845, 468.094738]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757829},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'parallel',
#     'laneStyle': 'dashed',
#     'laneType': 'single white'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[517.973687, 416.936845],
#       [553.784213, 437.400002]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757830},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'parallel',
#     'laneStyle': 'dashed',
#     'laneType': 'single white'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[512.857898, 409.26316], [558.900002, 434.842108]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757831},
#   {'category': 'lane',
#    'attributes': {'laneDirection': 'vertical',
#     'laneStyle': 'dashed',
#     'laneType': 'crosswalk'},
#    'manualShape': True,
#    'manualAttributes': True,
#    'poly2d': [{'vertices': [[919.563162, 428.447372],
#       [957.931584, 432.284212]],
#      'types': 'LL',
#      'closed': False}],
#    'id': 757832}]}

# %% [markdown]
# ## Helper functions

# %%
def get_labels(group, include):
    def filter_categories(label):
        return label['category'] in include
    
    return list(filter(filter_categories, group['labels']))

car_labels = get_labels(dataset[0], {'car'})

# %%
car_labels
# Out:
# [{'category': 'car',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 45.240919,
#    'y1': 254.530367,
#    'x2': 357.805838,
#    'y2': 487.906215},
#   'id': 4},
#  {'category': 'car',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 507.82755,
#    'y1': 221.727518,
#    'x2': 908.367588,
#    'y2': 442.715126},
#   'id': 5}]

# %% [markdown]
# ## Converts the dataset

# %%
def flatten_labels(include):
    labels = []
    
    # Iterates through each group in the dataset
    for i in range(dataset_len):
        group_labels = get_labels(dataset[i], include)
        
        # Iterates through each label from this group
        for j in range(len(group_labels)):
            group_labels[j].update( {'name'       : dataset[i]['name']} )
            group_labels[j].update( {'properties' : dataset[i]['attributes']} )
            group_labels[j].update( {'timestamp'  : dataset[i]['timestamp']} )
        
        # Adds this group's labels to the list of labels
        labels = labels + group_labels
    return labels

pedestrian_data = flatten_labels({'person'})

# %%
pedestrian_data
# Out:
# [{'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 423.158909,
#    'y1': 336.241987,
#    'x2': 434.176547,
#    'y2': 358.277263},
#   'id': 14,
#   'name': '0000f77c-62c2a288.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'highway',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 563.939839,
#    'y1': 324.000165,
#    'x2': 573.733294,
#    'y2': 348.483804},
#   'id': 15,
#   'name': '0000f77c-62c2a288.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'highway',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 656.977672,
#    'y1': 315.838956,
#    'x2': 666.771127,
#    'y2': 345.219323},
#   'id': 16,
#   'name': '0000f77c-62c2a288.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'highway',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 695.316564,
#    'y1': 343.179158,
#    'x2': 712.961393,
#    'y2': 386.140482},
#   'id': 60,
#   'name': '0001542f-7c670be8.jpg',
#   'properties': {'weather': 'clear', 'scene': 'highway', 'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 912.122852,
#    'y1': 350.279126,
#    'x2': 949.046862,
#    'y2': 436.1025},
#   'id': 133,
#   'name': '00067cfb-5443fe39.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 199.056526,
#    'y1': 335.816133,
#    'x2': 316.518755,
#    'y2': 604.510982},
#   'id': 206,
#   'name': '00067cfb-e535423e.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 727.531679,
#    'y1': 390.56191,
#    'x2': 745.151014,
#    'y2': 444.888191},
#   'id': 207,
#   'name': '00067cfb-e535423e.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 862.61324,
#    'y1': 384.688798,
#    'x2': 877.296017,
#    'y2': 433.141967},
#   'id': 208,
#   'name': '00067cfb-e535423e.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 884.637407,
#    'y1': 383.22052,
#    'x2': 896.383632,
#    'y2': 419.927465},
#   'id': 209,
#   'name': '00067cfb-e535423e.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 872.891186,
#    'y1': 384.688798,
#    'x2': 890.510521,
#    'y2': 434.610245},
#   'id': 210,
#   'name': '00067cfb-e535423e.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 852.335296,
#    'y1': 389.093632,
#    'x2': 868.486352,
#    'y2': 434.610248},
#   'id': 211,
#   'name': '00067cfb-e535423e.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 790.667626,
#    'y1': 381.752242,
#    'x2': 817.096628,
#    'y2': 453.697858},
#   'id': 212,
#   'name': '00067cfb-e535423e.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 731.936512,
#    'y1': 397.903299,
#    'x2': 792.135904,
#    'y2': 543.262806},
#   'id': 213,
#   'name': '00067cfb-e535423e.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 883.169131,
#    'y1': 384.688798,
#    'x2': 903.725022,
#    'y2': 455.166134},
#   'id': 214,
#   'name': '00067cfb-e535423e.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1097.322996,
#    'y1': 307.026412,
#    'x2': 1127.276793,
#    'y2': 381.910902},
#   'id': 292,
#   'name': '0008a165-c48f4b3e.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'highway',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 629.261939,
#    'y1': 375.249876,
#    'x2': 643.944715,
#    'y2': 410.488545},
#   'id': 355,
#   'name': '00091078-84635cf2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 676.246831,
#    'y1': 378.186435,
#    'x2': 696.802719,
#    'y2': 409.02027},
#   'id': 357,
#   'name': '00091078-84635cf2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 712.953778,
#    'y1': 369.37676,
#    'x2': 737.914501,
#    'y2': 410.488539},
#   'id': 358,
#   'name': '00091078-84635cf2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 739.382779,
#    'y1': 363.503648,
#    'x2': 768.748336,
#    'y2': 409.020261},
#   'id': 359,
#   'name': '00091078-84635cf2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 981.648624,
#    'y1': 340.011201,
#    'x2': 1016.887292,
#    'y2': 433.980984},
#   'id': 360,
#   'name': '00091078-84635cf2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1037.443182,
#    'y1': 344.416038,
#    'x2': 1065.340458,
#    'y2': 375.249873},
#   'id': 361,
#   'name': '00091078-84635cf2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 790.772505,
#    'y1': 359.098816,
#    'x2': 815.733228,
#    'y2': 414.893373},
#   'id': 362,
#   'name': '00091078-84635cf2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 815.733228,
#    'y1': 363.503648,
#    'x2': 834.820839,
#    'y2': 414.893375},
#   'id': 363,
#   'name': '00091078-84635cf2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 836.289118,
#    'y1': 351.757426,
#    'x2': 867.122951,
#    'y2': 417.82993},
#   'id': 364,
#   'name': '00091078-84635cf2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 865.654672,
#    'y1': 357.630538,
#    'x2': 902.361619,
#    'y2': 422.234763},
#   'id': 365,
#   'name': '00091078-84635cf2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 902.361619,
#    'y1': 354.693983,
#    'x2': 933.195457,
#    'y2': 435.449265},
#   'id': 366,
#   'name': '00091078-84635cf2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 937.600289,
#    'y1': 341.479481,
#    'x2': 978.712069,
#    'y2': 444.258929},
#   'id': 367,
#   'name': '00091078-84635cf2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1178.376714,
#    'y1': 317.386876,
#    'x2': 1247.805236,
#    'y2': 454.629304},
#   'id': 368,
#   'name': '00091078-84635cf2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1120.250509,
#    'y1': 330.30381,
#    'x2': 1152.542848,
#    'y2': 412.649262},
#   'id': 369,
#   'name': '00091078-84635cf2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': True,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1240.223695,
#    'y1': 360.852841,
#    'x2': 1278.612295,
#    'y2': 480.625275},
#   'id': 382,
#   'name': '00091078-875c1f73.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 740.746179,
#    'y1': 375.879131,
#    'x2': 764.238624,
#    'y2': 439.015079},
#   'id': 390,
#   'name': '00091078-c1d32eea.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 790.667627,
#    'y1': 370.006019,
#    'x2': 815.628353,
#    'y2': 433.141966},
#   'id': 391,
#   'name': '00091078-c1d32eea.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 324.341136,
#    'y1': 294.669551,
#    'x2': 338.665352,
#    'y2': 323.317979},
#   'id': 408,
#   'name': '00091078-cedbfea7.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 824.931723,
#    'y1': 378.527296,
#    'x2': 860.93172,
#    'y2': 457.277287},
#   'id': 426,
#   'name': '00091078-f32de4d2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': True,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1253.55667,
#    'y1': 345.902301,
#    'x2': 1278.306667,
#    'y2': 441.527291},
#   'id': 431,
#   'name': '00091078-f32de4d2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1006.937512,
#    'y1': 371.830705,
#    'x2': 1025.653823,
#    'y2': 419.245358},
#   'id': 432,
#   'name': '00091078-f32de4d2.jpg',
#   'properties': {'weather': 'snowy',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 823.731954,
#    'y1': 362.778053,
#    'x2': 857.407554,
#    'y2': 422.475708},
#   'id': 435,
#   'name': '000d35d3-41990aa4.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 878.837483,
#    'y1': 358.185925,
#    'x2': 906.390247,
#    'y2': 425.537126},
#   'id': 436,
#   'name': '000d35d3-41990aa4.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 923.228047,
#    'y1': 352.06309,
#    'x2': 949.250101,
#    'y2': 425.537126},
#   'id': 437,
#   'name': '000d35d3-41990aa4.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 970.680027,
#    'y1': 340.837886,
#    'x2': 1008.947754,
#    'y2': 450.028471},
#   'id': 438,
#   'name': '000d35d3-41990aa4.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1041.092646,
#    'y1': 361.247346,
#    'x2': 1080.891082,
#    'y2': 448.497764},
#   'id': 439,
#   'name': '000d35d3-41990aa4.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1013.539883,
#    'y1': 344.409543,
#    'x2': 1034.96981,
#    'y2': 422.475706},
#   'id': 440,
#   'name': '000d35d3-41990aa4.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1030.377681,
#    'y1': 355.124508,
#    'x2': 1051.80761,
#    'y2': 431.659961},
#   'id': 441,
#   'name': '000d35d3-41990aa4.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 697.493103,
#    'y1': 356.144978,
#    'x2': 718.92303,
#    'y2': 405.127666},
#   'id': 460,
#   'name': '000d35d3-41990aa4.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 686.778139,
#    'y1': 356.655217,
#    'x2': 703.615939,
#    'y2': 391.861526},
#   'id': 461,
#   'name': '000d35d3-41990aa4.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 723.515159,
#    'y1': 356.144978,
#    'x2': 744.945086,
#    'y2': 397.474122},
#   'id': 462,
#   'name': '000d35d3-41990aa4.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 746.475793,
#    'y1': 353.083558,
#    'x2': 765.565011,
#    'y2': 399.515071},
#   'id': 463,
#   'name': '000d35d3-41990aa4.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 762.503593,
#    'y1': 358.185926,
#    'x2': 776.279973,
#    'y2': 397.984362},
#   'id': 465,
#   'name': '000d35d3-41990aa4.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 394.290278,
#    'y1': 361.848671,
#    'x2': 401.776795,
#    'y2': 378.069476},
#   'id': 516,
#   'name': '000e0252-8523a4a9.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1005.963919,
#    'y1': 329.491759,
#    'x2': 1014.950058,
#    'y2': 360.943245},
#   'id': 610,
#   'name': '000f157f-37797ff9.jpg',
#   'properties': {'weather': 'clear', 'scene': 'highway', 'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 996.977779,
#    'y1': 330.989448,
#    'x2': 1002.968538,
#    'y2': 357.947864},
#   'id': 611,
#   'name': '000f157f-37797ff9.jpg',
#   'properties': {'weather': 'clear', 'scene': 'highway', 'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1074.857649,
#    'y1': 314.514861,
#    'x2': 1095.825306,
#    'y2': 363.938625},
#   'id': 612,
#   'name': '000f157f-37797ff9.jpg',
#   'properties': {'weather': 'clear', 'scene': 'highway', 'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1136.262931,
#    'y1': 307.026411,
#    'x2': 1155.7329,
#    'y2': 344.468656},
#   'id': 613,
#   'name': '000f157f-37797ff9.jpg',
#   'properties': {'weather': 'clear', 'scene': 'highway', 'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 195.981891,
#    'y1': 293.962293,
#    'x2': 222.981873,
#    'y2': 380.024735},
#   'id': 623,
#   'name': '000f157f-dab3a407.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 136.919432,
#    'y1': 288.899797,
#    'x2': 168.98191,
#    'y2': 374.962238},
#   'id': 624,
#   'name': '000f157f-dab3a407.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 116.669447,
#    'y1': 287.212297,
#    'x2': 138.60693,
#    'y2': 368.212241},
#   'id': 625,
#   'name': '000f157f-dab3a407.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 354.606782,
#    'y1': 307.462285,
#    'x2': 371.481771,
#    'y2': 334.462266},
#   'id': 626,
#   'name': '000f157f-dab3a407.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 386.669261,
#    'y1': 307.462285,
#    'x2': 398.481752,
#    'y2': 339.524763},
#   'id': 627,
#   'name': '000f157f-dab3a407.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 401.856751,
#    'y1': 300.712288,
#    'x2': 422.106737,
#    'y2': 339.524763},
#   'id': 628,
#   'name': '000f157f-dab3a407.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1124.106254,
#    'y1': 305.774785,
#    'x2': 1184.856213,
#    'y2': 447.524686},
#   'id': 629,
#   'name': '000f157f-dab3a407.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 106.544453,
#    'y1': 344.587258,
#    'x2': 131.856935,
#    'y2': 412.087213},
#   'id': 670,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 82.919469,
#    'y1': 341.21226,
#    'x2': 106.544453,
#    'y2': 412.087213},
#   'id': 671,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 246.606857,
#    'y1': 327.71227,
#    'x2': 276.981836,
#    'y2': 400.274721},
#   'id': 672,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 39.044499,
#    'y1': 347.962256,
#    'x2': 64.356982,
#    'y2': 412.087212},
#   'id': 673,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 229.731868,
#    'y1': 332.774766,
#    'x2': 248.294355,
#    'y2': 396.899721},
#   'id': 674,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 266.856843,
#    'y1': 334.462265,
#    'x2': 287.106828,
#    'y2': 395.212222},
#   'id': 675,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 847.356444,
#    'y1': 327.71227,
#    'x2': 860.856434,
#    'y2': 359.774749},
#   'id': 676,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 989.106346,
#    'y1': 342.899759,
#    'x2': 1019.481325,
#    'y2': 385.08723},
#   'id': 677,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 3.607024,
#    'y1': 341.21226,
#    'x2': 33.982003,
#    'y2': 422.212205},
#   'id': 678,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': True,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 0, 'y1': 347.962256, 'x2': 13.732018, 'y2': 410.399712},
#   'id': 679,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 536.184128,
#    'y1': 297.871006,
#    'x2': 550.293806,
#    'y2': 332.361334},
#   'id': 728,
#   'name': '0010bf16-9ee17cd9.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 760.371252,
#    'y1': 304.141975,
#    'x2': 785.455129,
#    'y2': 376.258113},
#   'id': 729,
#   'name': '0010bf16-9ee17cd9.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 785.455127,
#    'y1': 297.871006,
#    'x2': 816.809969,
#    'y2': 379.393597},
#   'id': 730,
#   'name': '0010bf16-9ee17cd9.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 853.463765,
#    'y1': 257.037333,
#    'x2': 870.932322,
#    'y2': 290.726692},
#   'id': 773,
#   'name': '00131ea7-624f538d.jpg',
#   'properties': {'weather': 'overcast',
#    'scene': 'highway',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 781.09403,
#    'y1': 258.285087,
#    'x2': 797.314833,
#    'y2': 311.93851},
#   'id': 774,
#   'name': '00131ea7-624f538d.jpg',
#   'properties': {'weather': 'overcast',
#    'scene': 'highway',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 766.120982,
#    'y1': 260.780595,
#    'x2': 782.341786,
#    'y2': 309.443003},
#   'id': 775,
#   'name': '00131ea7-624f538d.jpg',
#   'properties': {'weather': 'overcast',
#    'scene': 'highway',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 679.191746,
#    'y1': 248.216903,
#    'x2': 692.371404,
#    'y2': 271.281303},
#   'id': 863,
#   'name': '001bad4e-2fa8f3b6.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 696.764624,
#    'y1': 242.725379,
#    'x2': 703.354452,
#    'y2': 270.183},
#   'id': 864,
#   'name': '001bad4e-2fa8f3b6.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 700.059537,
#    'y1': 243.823683,
#    'x2': 713.239196,
#    'y2': 275.674526},
#   'id': 865,
#   'name': '001bad4e-2fa8f3b6.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 686.879882,
#    'y1': 242.725379,
#    'x2': 700.05954,
#    'y2': 276.772829},
#   'id': 866,
#   'name': '001bad4e-2fa8f3b6.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 747.286649,
#    'y1': 237.233852,
#    'x2': 767.056136,
#    'y2': 267.98639},
#   'id': 867,
#   'name': '001bad4e-2fa8f3b6.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 14.872971,
#    'y1': 296.20129,
#    'x2': 43.630378,
#    'y2': 353.716104},
#   'id': 910,
#   'name': '001c5339-08faca55.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 868.967954,
#    'y1': 322.082956,
#    'x2': 896.287491,
#    'y2': 385.349253},
#   'id': 911,
#   'name': '001c5339-08faca55.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 867.530084,
#    'y1': 330.710179,
#    'x2': 896.287491,
#    'y2': 388.224992},
#   'id': 912,
#   'name': '001c5339-08faca55.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 696.599756,
#    'y1': 332.292736,
#    'x2': 708.749752,
#    'y2': 366.428441},
#   'id': 999,
#   'name': '001c5339-9a6cdd3e.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 742.499739,
#    'y1': 339.428451,
#    'x2': 753.299734,
#    'y2': 378.578439},
#   'id': 1000,
#   'name': '001c5339-9a6cdd3e.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 964.057881,
#    'y1': 255.637162,
#    'x2': 993.748607,
#    'y2': 325.410372},
#   'id': 1148,
#   'name': '00211b17-ad3e206b.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 987.99164,
#    'y1': 353.954018,
#    'x2': 1010.456987,
#    'y2': 406.373162},
#   'id': 1164,
#   'name': '00225f53-4200bde2.jpg',
#   'properties': {'weather': 'overcast',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 149.66901,
#    'y1': 395.904586,
#    'x2': 204.584254,
#    'y2': 544.175744},
#   'id': 1190,
#   'name': '00225f53-67614580.jpg',
#   'properties': {'weather': 'overcast',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 258.401193,
#    'y1': 381.626622,
#    'x2': 291.350339,
#    'y2': 496.948634},
#   'id': 1191,
#   'name': '00225f53-67614580.jpg',
#   'properties': {'weather': 'overcast',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 956.293459,
#    'y1': 294.818531,
#    'x2': 974.317299,
#    'y2': 334.728463},
#   'id': 1238,
#   'name': '00232de3-19eca24a.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 222.46567,
#    'y1': 306.405287,
#    'x2': 245.639179,
#    'y2': 356.614555},
#   'id': 1239,
#   'name': '00232de3-19eca24a.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 993.486305,
#    'y1': 172.657896,
#    'x2': 1010.112621,
#    'y2': 235.326318},
#   'id': 1383,
#   'name': '00268999-9f6d5823.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 976.85999,
#    'y1': 172.657896,
#    'x2': 996.0442,
#    'y2': 243.000002},
#   'id': 1384,
#   'name': '00268999-9f6d5823.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 947.444201, 'y1': 175.215789, 'x2': 971.744201, 'y2': 243},
#   'id': 1385,
#   'name': '00268999-9f6d5823.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 638.382143,
#    'y1': 155.256246,
#    'x2': 662.08947,
#    'y2': 196.432129},
#   'id': 1443,
#   'name': '002827ad-8748e2fb.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 904.153754,
#    'y1': 151.512984,
#    'x2': 912.888032,
#    'y2': 183.954589},
#   'id': 1444,
#   'name': '002827ad-8748e2fb.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 838.962497,
#    'y1': 438.302481,
#    'x2': 850.56462,
#    'y2': 464.084979},
#   'id': 1563,
#   'name': '002b485a-3f6603f2.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'night'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 945.381671,
#    'y1': 436.298001,
#    'x2': 969.088999,
#    'y2': 489.951425},
#   'id': 1690,
#   'name': '002d290d-01969e7d.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 909.196805,
#    'y1': 428.811478,
#    'x2': 941.63841,
#    'y2': 496.190196},
#   'id': 1691,
#   'name': '002d290d-01969e7d.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 847.640926,
#    'y1': 437.96167,
#    'x2': 865.109483,
#    'y2': 492.862846},
#   'id': 1693,
#   'name': '002d290d-01969e7d.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 866.357236,
#    'y1': 435.466162,
#    'x2': 887.569055,
#    'y2': 491.615091},
#   'id': 1694,
#   'name': '002d290d-01969e7d.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 892.560072,
#    'y1': 431.722899,
#    'x2': 907.533122,
#    'y2': 456.677981},
#   'id': 1695,
#   'name': '002d290d-01969e7d.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 999.035095,
#    'y1': 430.475147,
#    'x2': 1027.733438,
#    'y2': 489.119586},
#   'id': 1696,
#   'name': '002d290d-01969e7d.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 729.520221,
#    'y1': 420.909042,
#    'x2': 744.493273,
#    'y2': 439.625353},
#   'id': 1697,
#   'name': '002d290d-01969e7d.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 301.956479,
#    'y1': 442.120862,
#    'x2': 316.929529,
#    'y2': 480.801236},
#   'id': 1698,
#   'name': '002d290d-01969e7d.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 328.159314,
#    'y1': 438.377601,
#    'x2': 338.141347,
#    'y2': 452.102894},
#   'id': 1699,
#   'name': '002d290d-01969e7d.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 340.636855,
#    'y1': 438.377601,
#    'x2': 348.12338,
#    'y2': 453.350648},
#   'id': 1700,
#   'name': '002d290d-01969e7d.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 293.2222,
#    'y1': 447.111877,
#    'x2': 303.204232,
#    'y2': 464.580433},
#   'id': 1701,
#   'name': '002d290d-01969e7d.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 286.983431,
#    'y1': 444.616371,
#    'x2': 293.2222,
#    'y2': 460.837172},
#   'id': 1702,
#   'name': '002d290d-01969e7d.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 279.496907,
#    'y1': 443.368616,
#    'x2': 288.231185,
#    'y2': 462.084927},
#   'id': 1703,
#   'name': '002d290d-01969e7d.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 259.532842,
#    'y1': 444.616371,
#    'x2': 273.258137,
#    'y2': 460.837172},
#   'id': 1704,
#   'name': '002d290d-01969e7d.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 243.312038,
#    'y1': 447.111877,
#    'x2': 258.285088,
#    'y2': 462.084928},
#   'id': 1705,
#   'name': '002d290d-01969e7d.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'city street',
# ...
#    'x2': 321.00457,
#    'y2': 438.738477},
#   'id': 21380,
#   'name': '021cb34f-455d80a0.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 282.5639,
#    'y1': 356.365609,
#    'x2': 306.726607,
#    'y2': 446.42661},
#   'id': 21381,
#   'name': '021cb34f-455d80a0.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 259.499498,
#    'y1': 357.463915,
#    'x2': 281.465597,
#    'y2': 399.1995},
#   'id': 21382,
#   'name': '021cb34f-455d80a0.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 228.74696,
#    'y1': 354.169001,
#    'x2': 259.499497,
#    'y2': 399.1995},
#   'id': 21383,
#   'name': '021cb34f-455d80a0.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 485.725333,
#    'y1': 369.57959,
#    'x2': 503.29821,
#    'y2': 423.396531},
#   'id': 21384,
#   'name': '021cb34f-455d80a0.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 498.90499,
#    'y1': 367.38298,
#    'x2': 514.281256,
#    'y2': 425.593138},
#   'id': 21385,
#   'name': '021cb34f-455d80a0.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 453.87449,
#    'y1': 372.874505,
#    'x2': 465.95584,
#    'y2': 400.332128},
#   'id': 21386,
#   'name': '021cb34f-455d80a0.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 901.433726,
#    'y1': 338.827054,
#    'x2': 926.694738,
#    'y2': 424.494834},
#   'id': 21387,
#   'name': '021cb34f-455d80a0.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 920.10491,
#    'y1': 339.925359,
#    'x2': 944.267617,
#    'y2': 421.199919},
#   'id': 21388,
#   'name': '021cb34f-455d80a0.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 936.579484,
#    'y1': 325.647396,
#    'x2': 986.003204,
#    'y2': 428.888056},
#   'id': 21389,
#   'name': '021cb34f-455d80a0.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1136.470971,
#    'y1': 338.827054,
#    'x2': 1169.420118,
#    'y2': 414.573817},
#   'id': 21390,
#   'name': '021cb34f-455d80a0.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1106.816739,
#    'y1': 339.925359,
#    'x2': 1121.0947,
#    'y2': 403.627044},
#   'id': 21391,
#   'name': '021cb34f-455d80a0.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 987.101509,
#    'y1': 341.023663,
#    'x2': 1004.674387,
#    'y2': 400.332128},
#   'id': 21392,
#   'name': '021cb34f-455d80a0.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 883.859405,
#    'y1': 340.322596,
#    'x2': 904.670499,
#    'y2': 427.239521},
#   'id': 21404,
#   'name': '021cb34f-455d80a0.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1193.458012,
#    'y1': 293.698078,
#    'x2': 1242.40769,
#    'y2': 365.374395},
#   'id': 21451,
#   'name': '021df36f-9dc059b8.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1037.867958,
#    'y1': 276.21605,
#    'x2': 1058.846392,
#    'y2': 307.683701},
#   'id': 21452,
#   'name': '021df36f-9dc059b8.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 288.73479,
#    'y1': 282.33476,
#    'x2': 304.163368,
#    'y2': 331.243768},
#   'id': 21547,
#   'name': '02207cae-1e3da672.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 264.328279,
#    'y1': 297.194484,
#    'x2': 295.795932,
#    'y2': 368.870801},
#   'id': 21548,
#   'name': '02207cae-1e3da672.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 300.857244,
#    'y1': 301.488653,
#    'x2': 325.102153,
#    'y2': 356.590719},
#   'id': 21550,
#   'name': '02207cae-1e3da672.jpg',
#   'properties': {'weather': 'rainy',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 832.16043,
#    'y1': 315.213499,
#    'x2': 849.733308,
#    'y2': 333.884679},
#   'id': 21598,
#   'name': '02269962-0e3f5114.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'residential',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 711.684197,
#    'y1': 467.332433,
#    'x2': 718.121281,
#    'y2': 478.919188},
#   'id': 21887,
#   'name': '022ba62d-853f4ad1.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 697.522606,
#    'y1': 464.757599,
#    'x2': 709.109362,
#    'y2': 482.781439},
#   'id': 21888,
#   'name': '022ba62d-853f4ad1.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 612.553075,
#    'y1': 462.182764,
#    'x2': 626.714664,
#    'y2': 507.242366},
#   'id': 21890,
#   'name': '022ba62d-853f4ad1.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 598.391485,
#    'y1': 468.61985,
#    'x2': 613.840491,
#    'y2': 511.104616},
#   'id': 21891,
#   'name': '022ba62d-853f4ad1.jpg',
#   'properties': {'weather': 'undefined',
#    'scene': 'city street',
#    'timeofday': 'dawn/dusk'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 1115.492113,
#    'y1': 455.430226,
#    'x2': 1244.01078,
#    'y2': 701.237772},
#   'id': 21925,
#   'name': '022da1b8-ab52d480.jpg',
#   'properties': {'weather': 'partly cloudy',
#    'scene': 'residential',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 712.114761,
#    'y1': 383.709948,
#    'x2': 723.860984,
#    'y2': 402.308132},
#   'id': 21972,
#   'name': '0232ae80-e2da554a.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 703.305092,
#    'y1': 381.752242,
#    'x2': 717.00902,
#    'y2': 415.033207},
#   'id': 21973,
#   'name': '0232ae80-e2da554a.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 697.431983,
#    'y1': 380.773391,
#    'x2': 714.072465,
#    'y2': 412.096653},
#   'id': 21974,
#   'name': '0232ae80-e2da554a.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 689.601168,
#    'y1': 380.773391,
#    'x2': 698.410835,
#    'y2': 394.477319},
#   'id': 21975,
#   'name': '0232ae80-e2da554a.jpg',
#   'properties': {'weather': 'clear',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 2.516273,
#    'y1': 329.991242,
#    'x2': 22.646459,
#    'y2': 376.003093},
#   'id': 22064,
#   'name': '0233c21b-577418b6.jpg',
#   'properties': {'weather': 'overcast',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 149.179048,
#    'y1': 329.991242,
#    'x2': 160.682011,
#    'y2': 360.186521},
#   'id': 22065,
#   'name': '0233c21b-577418b6.jpg',
#   'properties': {'weather': 'overcast',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 169.309233,
#    'y1': 328.553373,
#    'x2': 180.812196,
#    'y2': 363.062261},
#   'id': 22066,
#   'name': '0233c21b-577418b6.jpg',
#   'properties': {'weather': 'overcast',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 157.806271,
#    'y1': 328.553373,
#    'x2': 170.747104,
#    'y2': 363.062261},
#   'id': 22067,
#   'name': '0233c21b-577418b6.jpg',
#   'properties': {'weather': 'overcast',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 797.658572,
#    'y1': 335.742725,
#    'x2': 814.913015,
#    'y2': 383.192447},
#   'id': 22068,
#   'name': '0233c21b-577418b6.jpg',
#   'properties': {'weather': 'overcast',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 819.226627,
#    'y1': 334.304854,
#    'x2': 835.043201,
#    'y2': 381.754576},
#   'id': 22069,
#   'name': '0233c21b-577418b6.jpg',
#   'properties': {'weather': 'overcast',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': True,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 850.859775,
#    'y1': 331.429114,
#    'x2': 868.114218,
#    'y2': 357.310779},
#   'id': 22070,
#   'name': '0233c21b-577418b6.jpg',
#   'properties': {'weather': 'overcast',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 662.49876,
#    'y1': 341.494205,
#    'x2': 676.877463,
#    'y2': 374.565224},
#   'id': 22071,
#   'name': '0233c21b-577418b6.jpg',
#   'properties': {'weather': 'overcast',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  {'category': 'person',
#   'attributes': {'occluded': False,
#    'truncated': False,
#    'trafficLightColor': 'none'},
#   'manualShape': True,
#   'manualAttributes': True,
#   'box2d': {'x1': 635.179224,
#    'y1': 340.056336,
#    'x2': 652.433667,
#    'y2': 371.689484},
#   'id': 22072,
#   'name': '0233c21b-577418b6.jpg',
#   'properties': {'weather': 'overcast',
#    'scene': 'city street',
#    'timeofday': 'daytime'},
#   'timestamp': 10000},
#  ...]

# %%
# Transforms the obtained data
def transform_data(transform, data):
    transformed_data = []
    
    # Transforms each row in the given data
    for label in data:
        new_label = dict(label)
        
        # Transforms the data with the given transform function
        transformed_label = transform(new_label)
        transformed_data.append(transformed_label)
    
    return transformed_data

# %%
# Adds new columns
def flatten_data(label):
    # flattens the box2d data
    label.update( {'x1' : label['box2d']['x1']} )
    label.update( {'y1' : label['box2d']['y1']} )
    label.update( {'x2' : label['box2d']['x2']} )
    label.update( {'y2' : label['box2d']['y2']} )
    
    # flattens the attributes data
    label.update( {'occluded'          : label['attributes']['occluded']} )
    label.update( {'truncated'         : label['attributes']['truncated']} )
    label.update( {'trafficLightColor' : label['attributes']['trafficLightColor']} )
    
    # flattens the attributes data
    label.update( {'weather'   : label['properties']['weather']} )
    label.update( {'scene'     : label['properties']['scene']} )
    label.update( {'timeofday' : label['properties']['timeofday']} )
    
    # removes the hierarchical data
    del label['box2d']
    del label['attributes']
    del label['properties']
    
    # returns the transformed data
    return label

# Deletes unused columns
def dump_columns(label):
    del label['manualShape']
    del label['manualAttributes']
    
    # returns the transformed data
    return label

# %%
flattened_data = transform_data(flatten_data, pedestrian_data)
cleaned_data = transform_data(dump_columns, flattened_data)

# %%
cleaned_data
# Out:
# [{'category': 'person',
#   'id': 14,
#   'name': '0000f77c-62c2a288.jpg',
#   'timestamp': 10000,
#   'x1': 423.158909,
#   'y1': 336.241987,
#   'x2': 434.176547,
#   'y2': 358.277263,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'highway',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 15,
#   'name': '0000f77c-62c2a288.jpg',
#   'timestamp': 10000,
#   'x1': 563.939839,
#   'y1': 324.000165,
#   'x2': 573.733294,
#   'y2': 348.483804,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'highway',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 16,
#   'name': '0000f77c-62c2a288.jpg',
#   'timestamp': 10000,
#   'x1': 656.977672,
#   'y1': 315.838956,
#   'x2': 666.771127,
#   'y2': 345.219323,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'highway',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 60,
#   'name': '0001542f-7c670be8.jpg',
#   'timestamp': 10000,
#   'x1': 695.316564,
#   'y1': 343.179158,
#   'x2': 712.961393,
#   'y2': 386.140482,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'highway',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 133,
#   'name': '00067cfb-5443fe39.jpg',
#   'timestamp': 10000,
#   'x1': 912.122852,
#   'y1': 350.279126,
#   'x2': 949.046862,
#   'y2': 436.1025,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 206,
#   'name': '00067cfb-e535423e.jpg',
#   'timestamp': 10000,
#   'x1': 199.056526,
#   'y1': 335.816133,
#   'x2': 316.518755,
#   'y2': 604.510982,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 207,
#   'name': '00067cfb-e535423e.jpg',
#   'timestamp': 10000,
#   'x1': 727.531679,
#   'y1': 390.56191,
#   'x2': 745.151014,
#   'y2': 444.888191,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 208,
#   'name': '00067cfb-e535423e.jpg',
#   'timestamp': 10000,
#   'x1': 862.61324,
#   'y1': 384.688798,
#   'x2': 877.296017,
#   'y2': 433.141967,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 209,
#   'name': '00067cfb-e535423e.jpg',
#   'timestamp': 10000,
#   'x1': 884.637407,
#   'y1': 383.22052,
#   'x2': 896.383632,
#   'y2': 419.927465,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 210,
#   'name': '00067cfb-e535423e.jpg',
#   'timestamp': 10000,
#   'x1': 872.891186,
#   'y1': 384.688798,
#   'x2': 890.510521,
#   'y2': 434.610245,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 211,
#   'name': '00067cfb-e535423e.jpg',
#   'timestamp': 10000,
#   'x1': 852.335296,
#   'y1': 389.093632,
#   'x2': 868.486352,
#   'y2': 434.610248,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 212,
#   'name': '00067cfb-e535423e.jpg',
#   'timestamp': 10000,
#   'x1': 790.667626,
#   'y1': 381.752242,
#   'x2': 817.096628,
#   'y2': 453.697858,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 213,
#   'name': '00067cfb-e535423e.jpg',
#   'timestamp': 10000,
#   'x1': 731.936512,
#   'y1': 397.903299,
#   'x2': 792.135904,
#   'y2': 543.262806,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 214,
#   'name': '00067cfb-e535423e.jpg',
#   'timestamp': 10000,
#   'x1': 883.169131,
#   'y1': 384.688798,
#   'x2': 903.725022,
#   'y2': 455.166134,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 292,
#   'name': '0008a165-c48f4b3e.jpg',
#   'timestamp': 10000,
#   'x1': 1097.322996,
#   'y1': 307.026412,
#   'x2': 1127.276793,
#   'y2': 381.910902,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'highway',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 355,
#   'name': '00091078-84635cf2.jpg',
#   'timestamp': 10000,
#   'x1': 629.261939,
#   'y1': 375.249876,
#   'x2': 643.944715,
#   'y2': 410.488545,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 357,
#   'name': '00091078-84635cf2.jpg',
#   'timestamp': 10000,
#   'x1': 676.246831,
#   'y1': 378.186435,
#   'x2': 696.802719,
#   'y2': 409.02027,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 358,
#   'name': '00091078-84635cf2.jpg',
#   'timestamp': 10000,
#   'x1': 712.953778,
#   'y1': 369.37676,
#   'x2': 737.914501,
#   'y2': 410.488539,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 359,
#   'name': '00091078-84635cf2.jpg',
#   'timestamp': 10000,
#   'x1': 739.382779,
#   'y1': 363.503648,
#   'x2': 768.748336,
#   'y2': 409.020261,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 360,
#   'name': '00091078-84635cf2.jpg',
#   'timestamp': 10000,
#   'x1': 981.648624,
#   'y1': 340.011201,
#   'x2': 1016.887292,
#   'y2': 433.980984,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 361,
#   'name': '00091078-84635cf2.jpg',
#   'timestamp': 10000,
#   'x1': 1037.443182,
#   'y1': 344.416038,
#   'x2': 1065.340458,
#   'y2': 375.249873,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 362,
#   'name': '00091078-84635cf2.jpg',
#   'timestamp': 10000,
#   'x1': 790.772505,
#   'y1': 359.098816,
#   'x2': 815.733228,
#   'y2': 414.893373,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 363,
#   'name': '00091078-84635cf2.jpg',
#   'timestamp': 10000,
#   'x1': 815.733228,
#   'y1': 363.503648,
#   'x2': 834.820839,
#   'y2': 414.893375,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 364,
#   'name': '00091078-84635cf2.jpg',
#   'timestamp': 10000,
#   'x1': 836.289118,
#   'y1': 351.757426,
#   'x2': 867.122951,
#   'y2': 417.82993,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 365,
#   'name': '00091078-84635cf2.jpg',
#   'timestamp': 10000,
#   'x1': 865.654672,
#   'y1': 357.630538,
#   'x2': 902.361619,
#   'y2': 422.234763,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 366,
#   'name': '00091078-84635cf2.jpg',
#   'timestamp': 10000,
#   'x1': 902.361619,
#   'y1': 354.693983,
#   'x2': 933.195457,
#   'y2': 435.449265,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 367,
#   'name': '00091078-84635cf2.jpg',
#   'timestamp': 10000,
#   'x1': 937.600289,
#   'y1': 341.479481,
#   'x2': 978.712069,
#   'y2': 444.258929,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 368,
#   'name': '00091078-84635cf2.jpg',
#   'timestamp': 10000,
#   'x1': 1178.376714,
#   'y1': 317.386876,
#   'x2': 1247.805236,
#   'y2': 454.629304,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 369,
#   'name': '00091078-84635cf2.jpg',
#   'timestamp': 10000,
#   'x1': 1120.250509,
#   'y1': 330.30381,
#   'x2': 1152.542848,
#   'y2': 412.649262,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 382,
#   'name': '00091078-875c1f73.jpg',
#   'timestamp': 10000,
#   'x1': 1240.223695,
#   'y1': 360.852841,
#   'x2': 1278.612295,
#   'y2': 480.625275,
#   'occluded': True,
#   'truncated': True,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 390,
#   'name': '00091078-c1d32eea.jpg',
#   'timestamp': 10000,
#   'x1': 740.746179,
#   'y1': 375.879131,
#   'x2': 764.238624,
#   'y2': 439.015079,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 391,
#   'name': '00091078-c1d32eea.jpg',
#   'timestamp': 10000,
#   'x1': 790.667627,
#   'y1': 370.006019,
#   'x2': 815.628353,
#   'y2': 433.141966,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 408,
#   'name': '00091078-cedbfea7.jpg',
#   'timestamp': 10000,
#   'x1': 324.341136,
#   'y1': 294.669551,
#   'x2': 338.665352,
#   'y2': 323.317979,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 426,
#   'name': '00091078-f32de4d2.jpg',
#   'timestamp': 10000,
#   'x1': 824.931723,
#   'y1': 378.527296,
#   'x2': 860.93172,
#   'y2': 457.277287,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 431,
#   'name': '00091078-f32de4d2.jpg',
#   'timestamp': 10000,
#   'x1': 1253.55667,
#   'y1': 345.902301,
#   'x2': 1278.306667,
#   'y2': 441.527291,
#   'occluded': False,
#   'truncated': True,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 432,
#   'name': '00091078-f32de4d2.jpg',
#   'timestamp': 10000,
#   'x1': 1006.937512,
#   'y1': 371.830705,
#   'x2': 1025.653823,
#   'y2': 419.245358,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 435,
#   'name': '000d35d3-41990aa4.jpg',
#   'timestamp': 10000,
#   'x1': 823.731954,
#   'y1': 362.778053,
#   'x2': 857.407554,
#   'y2': 422.475708,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 436,
#   'name': '000d35d3-41990aa4.jpg',
#   'timestamp': 10000,
#   'x1': 878.837483,
#   'y1': 358.185925,
#   'x2': 906.390247,
#   'y2': 425.537126,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 437,
#   'name': '000d35d3-41990aa4.jpg',
#   'timestamp': 10000,
#   'x1': 923.228047,
#   'y1': 352.06309,
#   'x2': 949.250101,
#   'y2': 425.537126,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 438,
#   'name': '000d35d3-41990aa4.jpg',
#   'timestamp': 10000,
#   'x1': 970.680027,
#   'y1': 340.837886,
#   'x2': 1008.947754,
#   'y2': 450.028471,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 439,
#   'name': '000d35d3-41990aa4.jpg',
#   'timestamp': 10000,
#   'x1': 1041.092646,
#   'y1': 361.247346,
#   'x2': 1080.891082,
#   'y2': 448.497764,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 440,
#   'name': '000d35d3-41990aa4.jpg',
#   'timestamp': 10000,
#   'x1': 1013.539883,
#   'y1': 344.409543,
#   'x2': 1034.96981,
#   'y2': 422.475706,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 441,
#   'name': '000d35d3-41990aa4.jpg',
#   'timestamp': 10000,
#   'x1': 1030.377681,
#   'y1': 355.124508,
#   'x2': 1051.80761,
#   'y2': 431.659961,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 460,
#   'name': '000d35d3-41990aa4.jpg',
#   'timestamp': 10000,
#   'x1': 697.493103,
#   'y1': 356.144978,
#   'x2': 718.92303,
#   'y2': 405.127666,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 461,
#   'name': '000d35d3-41990aa4.jpg',
#   'timestamp': 10000,
#   'x1': 686.778139,
#   'y1': 356.655217,
#   'x2': 703.615939,
#   'y2': 391.861526,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 462,
#   'name': '000d35d3-41990aa4.jpg',
#   'timestamp': 10000,
#   'x1': 723.515159,
#   'y1': 356.144978,
#   'x2': 744.945086,
#   'y2': 397.474122,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 463,
#   'name': '000d35d3-41990aa4.jpg',
#   'timestamp': 10000,
#   'x1': 746.475793,
#   'y1': 353.083558,
#   'x2': 765.565011,
#   'y2': 399.515071,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 465,
#   'name': '000d35d3-41990aa4.jpg',
#   'timestamp': 10000,
#   'x1': 762.503593,
#   'y1': 358.185926,
#   'x2': 776.279973,
#   'y2': 397.984362,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 516,
#   'name': '000e0252-8523a4a9.jpg',
#   'timestamp': 10000,
#   'x1': 394.290278,
#   'y1': 361.848671,
#   'x2': 401.776795,
#   'y2': 378.069476,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 610,
#   'name': '000f157f-37797ff9.jpg',
#   'timestamp': 10000,
#   'x1': 1005.963919,
#   'y1': 329.491759,
#   'x2': 1014.950058,
#   'y2': 360.943245,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'highway',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 611,
#   'name': '000f157f-37797ff9.jpg',
#   'timestamp': 10000,
#   'x1': 996.977779,
#   'y1': 330.989448,
#   'x2': 1002.968538,
#   'y2': 357.947864,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'highway',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 612,
#   'name': '000f157f-37797ff9.jpg',
#   'timestamp': 10000,
#   'x1': 1074.857649,
#   'y1': 314.514861,
#   'x2': 1095.825306,
#   'y2': 363.938625,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'highway',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 613,
#   'name': '000f157f-37797ff9.jpg',
#   'timestamp': 10000,
#   'x1': 1136.262931,
#   'y1': 307.026411,
#   'x2': 1155.7329,
#   'y2': 344.468656,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'highway',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 623,
#   'name': '000f157f-dab3a407.jpg',
#   'timestamp': 10000,
#   'x1': 195.981891,
#   'y1': 293.962293,
#   'x2': 222.981873,
#   'y2': 380.024735,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 624,
#   'name': '000f157f-dab3a407.jpg',
#   'timestamp': 10000,
#   'x1': 136.919432,
#   'y1': 288.899797,
#   'x2': 168.98191,
#   'y2': 374.962238,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 625,
#   'name': '000f157f-dab3a407.jpg',
#   'timestamp': 10000,
#   'x1': 116.669447,
#   'y1': 287.212297,
#   'x2': 138.60693,
#   'y2': 368.212241,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 626,
#   'name': '000f157f-dab3a407.jpg',
#   'timestamp': 10000,
#   'x1': 354.606782,
#   'y1': 307.462285,
#   'x2': 371.481771,
#   'y2': 334.462266,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 627,
#   'name': '000f157f-dab3a407.jpg',
#   'timestamp': 10000,
#   'x1': 386.669261,
#   'y1': 307.462285,
#   'x2': 398.481752,
#   'y2': 339.524763,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 628,
#   'name': '000f157f-dab3a407.jpg',
#   'timestamp': 10000,
#   'x1': 401.856751,
#   'y1': 300.712288,
#   'x2': 422.106737,
#   'y2': 339.524763,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 629,
#   'name': '000f157f-dab3a407.jpg',
#   'timestamp': 10000,
#   'x1': 1124.106254,
#   'y1': 305.774785,
#   'x2': 1184.856213,
#   'y2': 447.524686,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 670,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'timestamp': 10000,
#   'x1': 106.544453,
#   'y1': 344.587258,
#   'x2': 131.856935,
#   'y2': 412.087213,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 671,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'timestamp': 10000,
#   'x1': 82.919469,
#   'y1': 341.21226,
#   'x2': 106.544453,
#   'y2': 412.087213,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 672,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'timestamp': 10000,
#   'x1': 246.606857,
#   'y1': 327.71227,
#   'x2': 276.981836,
#   'y2': 400.274721,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 673,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'timestamp': 10000,
#   'x1': 39.044499,
#   'y1': 347.962256,
#   'x2': 64.356982,
#   'y2': 412.087212,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 674,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'timestamp': 10000,
#   'x1': 229.731868,
#   'y1': 332.774766,
#   'x2': 248.294355,
#   'y2': 396.899721,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 675,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'timestamp': 10000,
#   'x1': 266.856843,
#   'y1': 334.462265,
#   'x2': 287.106828,
#   'y2': 395.212222,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 676,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'timestamp': 10000,
#   'x1': 847.356444,
#   'y1': 327.71227,
#   'x2': 860.856434,
#   'y2': 359.774749,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 677,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'timestamp': 10000,
#   'x1': 989.106346,
#   'y1': 342.899759,
#   'x2': 1019.481325,
#   'y2': 385.08723,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 678,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'timestamp': 10000,
#   'x1': 3.607024,
#   'y1': 341.21226,
#   'x2': 33.982003,
#   'y2': 422.212205,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 679,
#   'name': '000f8d37-d4c09a0f.jpg',
#   'timestamp': 10000,
#   'x1': 0,
#   'y1': 347.962256,
#   'x2': 13.732018,
#   'y2': 410.399712,
#   'occluded': False,
#   'truncated': True,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 728,
#   'name': '0010bf16-9ee17cd9.jpg',
#   'timestamp': 10000,
#   'x1': 536.184128,
#   'y1': 297.871006,
#   'x2': 550.293806,
#   'y2': 332.361334,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 729,
#   'name': '0010bf16-9ee17cd9.jpg',
#   'timestamp': 10000,
#   'x1': 760.371252,
#   'y1': 304.141975,
#   'x2': 785.455129,
#   'y2': 376.258113,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 730,
#   'name': '0010bf16-9ee17cd9.jpg',
#   'timestamp': 10000,
#   'x1': 785.455127,
#   'y1': 297.871006,
#   'x2': 816.809969,
#   'y2': 379.393597,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 773,
#   'name': '00131ea7-624f538d.jpg',
#   'timestamp': 10000,
#   'x1': 853.463765,
#   'y1': 257.037333,
#   'x2': 870.932322,
#   'y2': 290.726692,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'highway',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 774,
#   'name': '00131ea7-624f538d.jpg',
#   'timestamp': 10000,
#   'x1': 781.09403,
#   'y1': 258.285087,
#   'x2': 797.314833,
#   'y2': 311.93851,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'highway',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 775,
#   'name': '00131ea7-624f538d.jpg',
#   'timestamp': 10000,
#   'x1': 766.120982,
#   'y1': 260.780595,
#   'x2': 782.341786,
#   'y2': 309.443003,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'highway',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 863,
#   'name': '001bad4e-2fa8f3b6.jpg',
#   'timestamp': 10000,
#   'x1': 679.191746,
#   'y1': 248.216903,
#   'x2': 692.371404,
#   'y2': 271.281303,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 864,
#   'name': '001bad4e-2fa8f3b6.jpg',
#   'timestamp': 10000,
#   'x1': 696.764624,
#   'y1': 242.725379,
#   'x2': 703.354452,
#   'y2': 270.183,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 865,
#   'name': '001bad4e-2fa8f3b6.jpg',
#   'timestamp': 10000,
#   'x1': 700.059537,
#   'y1': 243.823683,
#   'x2': 713.239196,
#   'y2': 275.674526,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 866,
#   'name': '001bad4e-2fa8f3b6.jpg',
#   'timestamp': 10000,
#   'x1': 686.879882,
#   'y1': 242.725379,
#   'x2': 700.05954,
#   'y2': 276.772829,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 867,
#   'name': '001bad4e-2fa8f3b6.jpg',
#   'timestamp': 10000,
#   'x1': 747.286649,
#   'y1': 237.233852,
#   'x2': 767.056136,
#   'y2': 267.98639,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 910,
#   'name': '001c5339-08faca55.jpg',
#   'timestamp': 10000,
#   'x1': 14.872971,
#   'y1': 296.20129,
#   'x2': 43.630378,
#   'y2': 353.716104,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 911,
#   'name': '001c5339-08faca55.jpg',
#   'timestamp': 10000,
#   'x1': 868.967954,
#   'y1': 322.082956,
#   'x2': 896.287491,
#   'y2': 385.349253,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 912,
#   'name': '001c5339-08faca55.jpg',
#   'timestamp': 10000,
#   'x1': 867.530084,
#   'y1': 330.710179,
#   'x2': 896.287491,
#   'y2': 388.224992,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 999,
#   'name': '001c5339-9a6cdd3e.jpg',
#   'timestamp': 10000,
#   'x1': 696.599756,
#   'y1': 332.292736,
#   'x2': 708.749752,
#   'y2': 366.428441,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 1000,
#   'name': '001c5339-9a6cdd3e.jpg',
#   'timestamp': 10000,
#   'x1': 742.499739,
#   'y1': 339.428451,
#   'x2': 753.299734,
#   'y2': 378.578439,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 1148,
#   'name': '00211b17-ad3e206b.jpg',
#   'timestamp': 10000,
#   'x1': 964.057881,
#   'y1': 255.637162,
#   'x2': 993.748607,
#   'y2': 325.410372,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 1164,
#   'name': '00225f53-4200bde2.jpg',
#   'timestamp': 10000,
#   'x1': 987.99164,
#   'y1': 353.954018,
#   'x2': 1010.456987,
#   'y2': 406.373162,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1190,
#   'name': '00225f53-67614580.jpg',
#   'timestamp': 10000,
#   'x1': 149.66901,
#   'y1': 395.904586,
#   'x2': 204.584254,
#   'y2': 544.175744,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1191,
#   'name': '00225f53-67614580.jpg',
#   'timestamp': 10000,
#   'x1': 258.401193,
#   'y1': 381.626622,
#   'x2': 291.350339,
#   'y2': 496.948634,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1238,
#   'name': '00232de3-19eca24a.jpg',
#   'timestamp': 10000,
#   'x1': 956.293459,
#   'y1': 294.818531,
#   'x2': 974.317299,
#   'y2': 334.728463,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 1239,
#   'name': '00232de3-19eca24a.jpg',
#   'timestamp': 10000,
#   'x1': 222.46567,
#   'y1': 306.405287,
#   'x2': 245.639179,
#   'y2': 356.614555,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 1383,
#   'name': '00268999-9f6d5823.jpg',
#   'timestamp': 10000,
#   'x1': 993.486305,
#   'y1': 172.657896,
#   'x2': 1010.112621,
#   'y2': 235.326318,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1384,
#   'name': '00268999-9f6d5823.jpg',
#   'timestamp': 10000,
#   'x1': 976.85999,
#   'y1': 172.657896,
#   'x2': 996.0442,
#   'y2': 243.000002,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1385,
#   'name': '00268999-9f6d5823.jpg',
#   'timestamp': 10000,
#   'x1': 947.444201,
#   'y1': 175.215789,
#   'x2': 971.744201,
#   'y2': 243,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1443,
#   'name': '002827ad-8748e2fb.jpg',
#   'timestamp': 10000,
#   'x1': 638.382143,
#   'y1': 155.256246,
#   'x2': 662.08947,
#   'y2': 196.432129,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1444,
#   'name': '002827ad-8748e2fb.jpg',
#   'timestamp': 10000,
#   'x1': 904.153754,
#   'y1': 151.512984,
#   'x2': 912.888032,
#   'y2': 183.954589,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1563,
#   'name': '002b485a-3f6603f2.jpg',
#   'timestamp': 10000,
#   'x1': 838.962497,
#   'y1': 438.302481,
#   'x2': 850.56462,
#   'y2': 464.084979,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 1690,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 945.381671,
#   'y1': 436.298001,
#   'x2': 969.088999,
#   'y2': 489.951425,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1691,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 909.196805,
#   'y1': 428.811478,
#   'x2': 941.63841,
#   'y2': 496.190196,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1693,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 847.640926,
#   'y1': 437.96167,
#   'x2': 865.109483,
#   'y2': 492.862846,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1694,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 866.357236,
#   'y1': 435.466162,
#   'x2': 887.569055,
#   'y2': 491.615091,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1695,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 892.560072,
#   'y1': 431.722899,
#   'x2': 907.533122,
#   'y2': 456.677981,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1696,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 999.035095,
#   'y1': 430.475147,
#   'x2': 1027.733438,
#   'y2': 489.119586,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1697,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 729.520221,
#   'y1': 420.909042,
#   'x2': 744.493273,
#   'y2': 439.625353,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1698,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 301.956479,
#   'y1': 442.120862,
#   'x2': 316.929529,
#   'y2': 480.801236,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1699,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 328.159314,
#   'y1': 438.377601,
#   'x2': 338.141347,
#   'y2': 452.102894,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1700,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 340.636855,
#   'y1': 438.377601,
#   'x2': 348.12338,
#   'y2': 453.350648,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1701,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 293.2222,
#   'y1': 447.111877,
#   'x2': 303.204232,
#   'y2': 464.580433,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1702,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 286.983431,
#   'y1': 444.616371,
#   'x2': 293.2222,
#   'y2': 460.837172,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1703,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 279.496907,
#   'y1': 443.368616,
#   'x2': 288.231185,
#   'y2': 462.084927,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1704,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 259.532842,
#   'y1': 444.616371,
#   'x2': 273.258137,
#   'y2': 460.837172,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1705,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 243.312038,
#   'y1': 447.111877,
#   'x2': 258.285088,
#   'y2': 462.084928,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1706,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 224.595729,
#   'y1': 445.864124,
#   'x2': 237.07327,
#   'y2': 460.837171,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1707,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 232.082252,
#   'y1': 444.616371,
#   'x2': 243.312038,
#   'y2': 462.084927,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1708,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 215.86145,
#   'y1': 447.111877,
#   'x2': 224.595729,
#   'y2': 463.332679,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1709,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 199.640646,
#   'y1': 445.864124,
#   'x2': 212.118187,
#   'y2': 462.084927,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1710,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 143.491716,
#   'y1': 439.625353,
#   'x2': 153.473748,
#   'y2': 477.057974,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1711,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 152.225994,
#   'y1': 442.120862,
#   'x2': 162.208028,
#   'y2': 467.075944,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1719,
#   'name': '002d290d-01969e7d.jpg',
#   'timestamp': 10000,
#   'x1': 172.203043,
#   'y1': 439.209422,
#   'x2': 190.919354,
#   'y2': 469.15552,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1739,
#   'name': '002d290d-89d1aea8.jpg',
#   'timestamp': 10000,
#   'x1': 707.476542,
#   'y1': 394.290278,
#   'x2': 724.9451,
#   'y2': 441.704931,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1797,
#   'name': '002d290d-f9108a13.jpg',
#   'timestamp': 10000,
#   'x1': 90.101235,
#   'y1': 444.284059,
#   'x2': 110.063307,
#   'y2': 494.957012,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1798,
#   'name': '002d290d-f9108a13.jpg',
#   'timestamp': 10000,
#   'x1': 199.124859,
#   'y1': 445.819603,
#   'x2': 217.551388,
#   'y2': 498.0281,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1799,
#   'name': '002d290d-f9108a13.jpg',
#   'timestamp': 10000,
#   'x1': 209.873668,
#   'y1': 442.748515,
#   'x2': 229.835741,
#   'y2': 490.35038,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1806,
#   'name': '002d290d-f9108a13.jpg',
#   'timestamp': 10000,
#   'x1': 1003.749917,
#   'y1': 399.753281,
#   'x2': 1029.854165,
#   'y2': 458.103955,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1868,
#   'name': '002f8552-0cdd55c6.jpg',
#   'timestamp': 10000,
#   'x1': 1002.606337,
#   'y1': 243.337328,
#   'x2': 1038.043811,
#   'y2': 310.837281,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1869,
#   'name': '002f8552-0cdd55c6.jpg',
#   'timestamp': 10000,
#   'x1': 867.60643,
#   'y1': 255.149819,
#   'x2': 887.856416,
#   'y2': 293.962293,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1870,
#   'name': '002f8552-0cdd55c6.jpg',
#   'timestamp': 10000,
#   'x1': 852.418941,
#   'y1': 246.712325,
#   'x2': 874.356425,
#   'y2': 283.837302,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1871,
#   'name': '002f8552-0cdd55c6.jpg',
#   'timestamp': 10000,
#   'x1': 951.981372,
#   'y1': 250.087323,
#   'x2': 985.731348,
#   'y2': 319.274776,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1872,
#   'name': '002f8552-0cdd55c6.jpg',
#   'timestamp': 10000,
#   'x1': 104.856955,
#   'y1': 246.712325,
#   'x2': 147.044425,
#   'y2': 361.462247,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1887,
#   'name': '002f8552-0cdd55c6.jpg',
#   'timestamp': 10000,
#   'x1': 420.419238,
#   'y1': 248.399824,
#   'x2': 444.04422,
#   'y2': 282.149801,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1888,
#   'name': '002f8552-0cdd55c6.jpg',
#   'timestamp': 10000,
#   'x1': 162.231914,
#   'y1': 252.449826,
#   'x2': 189.231895,
#   'y2': 318.262282,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1889,
#   'name': '002f8552-0cdd55c6.jpg',
#   'timestamp': 10000,
#   'x1': 136.919433,
#   'y1': 250.762329,
#   'x2': 157.169418,
#   'y2': 330.074775,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 1919,
#   'name': '0030f434-3eb4a3a9.jpg',
#   'timestamp': 10000,
#   'x1': 456.67798,
#   'y1': 303.204232,
#   'x2': 485.376323,
#   'y2': 364.34418,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 2009,
#   'name': '00313a01-725ddf3a.jpg',
#   'timestamp': 10000,
#   'x1': 417.008887,
#   'y1': 300.456327,
#   'x2': 436.908106,
#   'y2': 344.846892,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 2123,
#   'name': '00322f82-286ab9b3.jpg',
#   'timestamp': 10000,
#   'x1': 1117.380175,
#   'y1': 339.867064,
#   'x2': 1149.626599,
#   'y2': 419.715352,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 2272,
#   'name': '0034a363-24f318c4.jpg',
#   'timestamp': 10000,
#   'x1': 341.992155,
#   'y1': 334.655964,
#   'x2': 355.977778,
#   'y2': 364.375413,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 2273,
#   'name': '0034a363-24f318c4.jpg',
#   'timestamp': 10000,
#   'x1': 326.25833,
#   'y1': 336.404167,
#   'x2': 338.49575,
#   'y2': 380.109238,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 2274,
#   'name': '0034a363-24f318c4.jpg',
#   'timestamp': 10000,
#   'x1': 355.977778,
#   'y1': 324.166747,
#   'x2': 371.711604,
#   'y2': 367.871818,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 2296,
#   'name': '0035afff-3295dbd6.jpg',
#   'timestamp': 10000,
#   'x1': 59.994566,
#   'y1': 379.398972,
#   'x2': 100.284722,
#   'y2': 446.549232,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 2416,
#   'name': '00378858-c5f802ac.jpg',
#   'timestamp': 10000,
#   'x1': 631.898477,
#   'y1': 366.58213,
#   'x2': 641.619991,
#   'y2': 390.885918,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 2424,
#   'name': '00378858-c5f802ac.jpg',
#   'timestamp': 10000,
#   'x1': 471.493481,
#   'y1': 377.518831,
#   'x2': 484.860563,
#   'y2': 420.050461,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 2425,
#   'name': '00378858-c5f802ac.jpg',
#   'timestamp': 10000,
#   'x1': 549.265599,
#   'y1': 365.366939,
#   'x2': 562.632685,
#   'y2': 417.620081,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 2703,
#   'name': '004071a4-ef4bf541.jpg',
#   'timestamp': 10000,
#   'x1': 168.749941,
#   'y1': 328.049885,
#   'x2': 330.749884,
#   'y2': 641.249776,
#   'occluded': False,
#   'truncated': True,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 2922,
#   'name': '004855fc-ff3946ad.jpg',
#   'timestamp': 10000,
#   'x1': 1039.437485,
#   'y1': 417.988881,
#   'x2': 1065.866489,
#   'y2': 489.44507,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'highway',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 2923,
#   'name': '004855fc-ff3946ad.jpg',
#   'timestamp': 10000,
#   'x1': 1137.322675,
#   'y1': 426.798548,
#   'x2': 1169.624786,
#   'y2': 534.472257,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'highway',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 2924,
#   'name': '004855fc-ff3946ad.jpg',
#   'timestamp': 10000,
#   'x1': 1172.561343,
#   'y1': 428.756252,
#   'x2': 1201.926902,
#   'y2': 520.76833,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'highway',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 3021,
#   'name': '0048f391-e9bfaf62.jpg',
#   'timestamp': 10000,
#   'x1': 626.179459,
#   'y1': 489.636631,
#   'x2': 639.403948,
#   'y2': 525.342746,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'residential',
# ...
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21173,
#   'name': '0218c5b0-145d6bbf.jpg',
#   'timestamp': 10000,
#   'x1': 817.255002,
#   'y1': 368.431693,
#   'x2': 827.738829,
#   'y2': 416.357769,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21179,
#   'name': '0218c5b0-145d6bbf.jpg',
#   'timestamp': 10000,
#   'x1': 1145.24907,
#   'y1': 383.408592,
#   'x2': 1164.719038,
#   'y2': 402.878559,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21180,
#   'name': '0218c5b0-145d6bbf.jpg',
#   'timestamp': 10000,
#   'x1': 1164.719038,
#   'y1': 386.403973,
#   'x2': 1178.198246,
#   'y2': 401.380871,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21192,
#   'name': '0218c5b0-ad70f9a0.jpg',
#   'timestamp': 10000,
#   'x1': 369.649546,
#   'y1': 368.165009,
#   'x2': 396.371198,
#   'y2': 440.90729,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21261,
#   'name': '021a0cdd-baff0e6d.jpg',
#   'timestamp': 10000,
#   'x1': 1164.605147,
#   'y1': 304.821318,
#   'x2': 1187.864603,
#   'y2': 335.425868,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'night'},
#  {'category': 'person',
#   'id': 21351,
#   'name': '021c4a16-f4d18785.jpg',
#   'timestamp': 10000,
#   'x1': 948.293072,
#   'y1': 364.34418,
#   'x2': 1000.698742,
#   'y2': 466.660012,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'residential',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21352,
#   'name': '021c4a16-f4d18785.jpg',
#   'timestamp': 10000,
#   'x1': 902.126173,
#   'y1': 360.600918,
#   'x2': 953.284089,
#   'y2': 475.394291,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'residential',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21353,
#   'name': '021c4a16-f4d18785.jpg',
#   'timestamp': 10000,
#   'x1': 870.932322,
#   'y1': 360.600918,
#   'x2': 910.860451,
#   'y2': 471.651028,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'snowy',
#   'scene': 'residential',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21377,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 392.394389,
#   'y1': 354.169001,
#   'x2': 434.12997,
#   'y2': 437.640169,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21378,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 352.855411,
#   'y1': 360.75883,
#   'x2': 377.018118,
#   'y2': 434.345258,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21379,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 316.611352,
#   'y1': 364.053745,
#   'x2': 336.380838,
#   'y2': 442.033391,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21380,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 301.235083,
#   'y1': 356.365609,
#   'x2': 321.00457,
#   'y2': 438.738477,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21381,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 282.5639,
#   'y1': 356.365609,
#   'x2': 306.726607,
#   'y2': 446.42661,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21382,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 259.499498,
#   'y1': 357.463915,
#   'x2': 281.465597,
#   'y2': 399.1995,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21383,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 228.74696,
#   'y1': 354.169001,
#   'x2': 259.499497,
#   'y2': 399.1995,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21384,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 485.725333,
#   'y1': 369.57959,
#   'x2': 503.29821,
#   'y2': 423.396531,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21385,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 498.90499,
#   'y1': 367.38298,
#   'x2': 514.281256,
#   'y2': 425.593138,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21386,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 453.87449,
#   'y1': 372.874505,
#   'x2': 465.95584,
#   'y2': 400.332128,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21387,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 901.433726,
#   'y1': 338.827054,
#   'x2': 926.694738,
#   'y2': 424.494834,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21388,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 920.10491,
#   'y1': 339.925359,
#   'x2': 944.267617,
#   'y2': 421.199919,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21389,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 936.579484,
#   'y1': 325.647396,
#   'x2': 986.003204,
#   'y2': 428.888056,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21390,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 1136.470971,
#   'y1': 338.827054,
#   'x2': 1169.420118,
#   'y2': 414.573817,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21391,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 1106.816739,
#   'y1': 339.925359,
#   'x2': 1121.0947,
#   'y2': 403.627044,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21392,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 987.101509,
#   'y1': 341.023663,
#   'x2': 1004.674387,
#   'y2': 400.332128,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21404,
#   'name': '021cb34f-455d80a0.jpg',
#   'timestamp': 10000,
#   'x1': 883.859405,
#   'y1': 340.322596,
#   'x2': 904.670499,
#   'y2': 427.239521,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21451,
#   'name': '021df36f-9dc059b8.jpg',
#   'timestamp': 10000,
#   'x1': 1193.458012,
#   'y1': 293.698078,
#   'x2': 1242.40769,
#   'y2': 365.374395,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21452,
#   'name': '021df36f-9dc059b8.jpg',
#   'timestamp': 10000,
#   'x1': 1037.867958,
#   'y1': 276.21605,
#   'x2': 1058.846392,
#   'y2': 307.683701,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21547,
#   'name': '02207cae-1e3da672.jpg',
#   'timestamp': 10000,
#   'x1': 288.73479,
#   'y1': 282.33476,
#   'x2': 304.163368,
#   'y2': 331.243768,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21548,
#   'name': '02207cae-1e3da672.jpg',
#   'timestamp': 10000,
#   'x1': 264.328279,
#   'y1': 297.194484,
#   'x2': 295.795932,
#   'y2': 368.870801,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21550,
#   'name': '02207cae-1e3da672.jpg',
#   'timestamp': 10000,
#   'x1': 300.857244,
#   'y1': 301.488653,
#   'x2': 325.102153,
#   'y2': 356.590719,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'rainy',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21598,
#   'name': '02269962-0e3f5114.jpg',
#   'timestamp': 10000,
#   'x1': 832.16043,
#   'y1': 315.213499,
#   'x2': 849.733308,
#   'y2': 333.884679,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'residential',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21887,
#   'name': '022ba62d-853f4ad1.jpg',
#   'timestamp': 10000,
#   'x1': 711.684197,
#   'y1': 467.332433,
#   'x2': 718.121281,
#   'y2': 478.919188,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 21888,
#   'name': '022ba62d-853f4ad1.jpg',
#   'timestamp': 10000,
#   'x1': 697.522606,
#   'y1': 464.757599,
#   'x2': 709.109362,
#   'y2': 482.781439,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 21890,
#   'name': '022ba62d-853f4ad1.jpg',
#   'timestamp': 10000,
#   'x1': 612.553075,
#   'y1': 462.182764,
#   'x2': 626.714664,
#   'y2': 507.242366,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 21891,
#   'name': '022ba62d-853f4ad1.jpg',
#   'timestamp': 10000,
#   'x1': 598.391485,
#   'y1': 468.61985,
#   'x2': 613.840491,
#   'y2': 511.104616,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'undefined',
#   'scene': 'city street',
#   'timeofday': 'dawn/dusk'},
#  {'category': 'person',
#   'id': 21925,
#   'name': '022da1b8-ab52d480.jpg',
#   'timestamp': 10000,
#   'x1': 1115.492113,
#   'y1': 455.430226,
#   'x2': 1244.01078,
#   'y2': 701.237772,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'partly cloudy',
#   'scene': 'residential',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21972,
#   'name': '0232ae80-e2da554a.jpg',
#   'timestamp': 10000,
#   'x1': 712.114761,
#   'y1': 383.709948,
#   'x2': 723.860984,
#   'y2': 402.308132,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21973,
#   'name': '0232ae80-e2da554a.jpg',
#   'timestamp': 10000,
#   'x1': 703.305092,
#   'y1': 381.752242,
#   'x2': 717.00902,
#   'y2': 415.033207,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21974,
#   'name': '0232ae80-e2da554a.jpg',
#   'timestamp': 10000,
#   'x1': 697.431983,
#   'y1': 380.773391,
#   'x2': 714.072465,
#   'y2': 412.096653,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 21975,
#   'name': '0232ae80-e2da554a.jpg',
#   'timestamp': 10000,
#   'x1': 689.601168,
#   'y1': 380.773391,
#   'x2': 698.410835,
#   'y2': 394.477319,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'clear',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 22064,
#   'name': '0233c21b-577418b6.jpg',
#   'timestamp': 10000,
#   'x1': 2.516273,
#   'y1': 329.991242,
#   'x2': 22.646459,
#   'y2': 376.003093,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 22065,
#   'name': '0233c21b-577418b6.jpg',
#   'timestamp': 10000,
#   'x1': 149.179048,
#   'y1': 329.991242,
#   'x2': 160.682011,
#   'y2': 360.186521,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 22066,
#   'name': '0233c21b-577418b6.jpg',
#   'timestamp': 10000,
#   'x1': 169.309233,
#   'y1': 328.553373,
#   'x2': 180.812196,
#   'y2': 363.062261,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 22067,
#   'name': '0233c21b-577418b6.jpg',
#   'timestamp': 10000,
#   'x1': 157.806271,
#   'y1': 328.553373,
#   'x2': 170.747104,
#   'y2': 363.062261,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 22068,
#   'name': '0233c21b-577418b6.jpg',
#   'timestamp': 10000,
#   'x1': 797.658572,
#   'y1': 335.742725,
#   'x2': 814.913015,
#   'y2': 383.192447,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 22069,
#   'name': '0233c21b-577418b6.jpg',
#   'timestamp': 10000,
#   'x1': 819.226627,
#   'y1': 334.304854,
#   'x2': 835.043201,
#   'y2': 381.754576,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 22070,
#   'name': '0233c21b-577418b6.jpg',
#   'timestamp': 10000,
#   'x1': 850.859775,
#   'y1': 331.429114,
#   'x2': 868.114218,
#   'y2': 357.310779,
#   'occluded': True,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 22071,
#   'name': '0233c21b-577418b6.jpg',
#   'timestamp': 10000,
#   'x1': 662.49876,
#   'y1': 341.494205,
#   'x2': 676.877463,
#   'y2': 374.565224,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  {'category': 'person',
#   'id': 22072,
#   'name': '0233c21b-577418b6.jpg',
#   'timestamp': 10000,
#   'x1': 635.179224,
#   'y1': 340.056336,
#   'x2': 652.433667,
#   'y2': 371.689484,
#   'occluded': False,
#   'truncated': False,
#   'trafficLightColor': 'none',
#   'weather': 'overcast',
#   'scene': 'city street',
#   'timeofday': 'daytime'},
#  ...]

# %% [markdown]
# ## Outputs the dataset

# %%
# Deletes unused columns
def formats_data(label):
    del label['category']
    del label['name']
    del label['occluded']
    del label['truncated']
    del label['weather']
    del label['scene']
    del label['timeofday']
    
    # returns the transformed data
    return label

# %%
output_data = transform_data(formats_data, cleaned_data)

# %%
output_data
# Out:
# [{'id': 14,
#   'timestamp': 10000,
#   'x1': 423.158909,
#   'y1': 336.241987,
#   'x2': 434.176547,
#   'y2': 358.277263,
#   'trafficLightColor': 'none'},
#  {'id': 15,
#   'timestamp': 10000,
#   'x1': 563.939839,
#   'y1': 324.000165,
#   'x2': 573.733294,
#   'y2': 348.483804,
#   'trafficLightColor': 'none'},
#  {'id': 16,
#   'timestamp': 10000,
#   'x1': 656.977672,
#   'y1': 315.838956,
#   'x2': 666.771127,
#   'y2': 345.219323,
#   'trafficLightColor': 'none'},
#  {'id': 60,
#   'timestamp': 10000,
#   'x1': 695.316564,
#   'y1': 343.179158,
#   'x2': 712.961393,
#   'y2': 386.140482,
#   'trafficLightColor': 'none'},
#  {'id': 133,
#   'timestamp': 10000,
#   'x1': 912.122852,
#   'y1': 350.279126,
#   'x2': 949.046862,
#   'y2': 436.1025,
#   'trafficLightColor': 'none'},
#  {'id': 206,
#   'timestamp': 10000,
#   'x1': 199.056526,
#   'y1': 335.816133,
#   'x2': 316.518755,
#   'y2': 604.510982,
#   'trafficLightColor': 'none'},
#  {'id': 207,
#   'timestamp': 10000,
#   'x1': 727.531679,
#   'y1': 390.56191,
#   'x2': 745.151014,
#   'y2': 444.888191,
#   'trafficLightColor': 'none'},
#  {'id': 208,
#   'timestamp': 10000,
#   'x1': 862.61324,
#   'y1': 384.688798,
#   'x2': 877.296017,
#   'y2': 433.141967,
#   'trafficLightColor': 'none'},
#  {'id': 209,
#   'timestamp': 10000,
#   'x1': 884.637407,
#   'y1': 383.22052,
#   'x2': 896.383632,
#   'y2': 419.927465,
#   'trafficLightColor': 'none'},
#  {'id': 210,
#   'timestamp': 10000,
#   'x1': 872.891186,
#   'y1': 384.688798,
#   'x2': 890.510521,
#   'y2': 434.610245,
#   'trafficLightColor': 'none'},
#  {'id': 211,
#   'timestamp': 10000,
#   'x1': 852.335296,
#   'y1': 389.093632,
#   'x2': 868.486352,
#   'y2': 434.610248,
#   'trafficLightColor': 'none'},
#  {'id': 212,
#   'timestamp': 10000,
#   'x1': 790.667626,
#   'y1': 381.752242,
#   'x2': 817.096628,
#   'y2': 453.697858,
#   'trafficLightColor': 'none'},
#  {'id': 213,
#   'timestamp': 10000,
#   'x1': 731.936512,
#   'y1': 397.903299,
#   'x2': 792.135904,
#   'y2': 543.262806,
#   'trafficLightColor': 'none'},
#  {'id': 214,
#   'timestamp': 10000,
#   'x1': 883.169131,
#   'y1': 384.688798,
#   'x2': 903.725022,
#   'y2': 455.166134,
#   'trafficLightColor': 'none'},
#  {'id': 292,
#   'timestamp': 10000,
#   'x1': 1097.322996,
#   'y1': 307.026412,
#   'x2': 1127.276793,
#   'y2': 381.910902,
#   'trafficLightColor': 'none'},
#  {'id': 355,
#   'timestamp': 10000,
#   'x1': 629.261939,
#   'y1': 375.249876,
#   'x2': 643.944715,
#   'y2': 410.488545,
#   'trafficLightColor': 'none'},
#  {'id': 357,
#   'timestamp': 10000,
#   'x1': 676.246831,
#   'y1': 378.186435,
#   'x2': 696.802719,
#   'y2': 409.02027,
#   'trafficLightColor': 'none'},
#  {'id': 358,
#   'timestamp': 10000,
#   'x1': 712.953778,
#   'y1': 369.37676,
#   'x2': 737.914501,
#   'y2': 410.488539,
#   'trafficLightColor': 'none'},
#  {'id': 359,
#   'timestamp': 10000,
#   'x1': 739.382779,
#   'y1': 363.503648,
#   'x2': 768.748336,
#   'y2': 409.020261,
#   'trafficLightColor': 'none'},
#  {'id': 360,
#   'timestamp': 10000,
#   'x1': 981.648624,
#   'y1': 340.011201,
#   'x2': 1016.887292,
#   'y2': 433.980984,
#   'trafficLightColor': 'none'},
#  {'id': 361,
#   'timestamp': 10000,
#   'x1': 1037.443182,
#   'y1': 344.416038,
#   'x2': 1065.340458,
#   'y2': 375.249873,
#   'trafficLightColor': 'none'},
#  {'id': 362,
#   'timestamp': 10000,
#   'x1': 790.772505,
#   'y1': 359.098816,
#   'x2': 815.733228,
#   'y2': 414.893373,
#   'trafficLightColor': 'none'},
#  {'id': 363,
#   'timestamp': 10000,
#   'x1': 815.733228,
#   'y1': 363.503648,
#   'x2': 834.820839,
#   'y2': 414.893375,
#   'trafficLightColor': 'none'},
#  {'id': 364,
#   'timestamp': 10000,
#   'x1': 836.289118,
#   'y1': 351.757426,
#   'x2': 867.122951,
#   'y2': 417.82993,
#   'trafficLightColor': 'none'},
#  {'id': 365,
#   'timestamp': 10000,
#   'x1': 865.654672,
#   'y1': 357.630538,
#   'x2': 902.361619,
#   'y2': 422.234763,
#   'trafficLightColor': 'none'},
#  {'id': 366,
#   'timestamp': 10000,
#   'x1': 902.361619,
#   'y1': 354.693983,
#   'x2': 933.195457,
#   'y2': 435.449265,
#   'trafficLightColor': 'none'},
#  {'id': 367,
#   'timestamp': 10000,
#   'x1': 937.600289,
#   'y1': 341.479481,
#   'x2': 978.712069,
#   'y2': 444.258929,
#   'trafficLightColor': 'none'},
#  {'id': 368,
#   'timestamp': 10000,
#   'x1': 1178.376714,
#   'y1': 317.386876,
#   'x2': 1247.805236,
#   'y2': 454.629304,
#   'trafficLightColor': 'none'},
#  {'id': 369,
#   'timestamp': 10000,
#   'x1': 1120.250509,
#   'y1': 330.30381,
#   'x2': 1152.542848,
#   'y2': 412.649262,
#   'trafficLightColor': 'none'},
#  {'id': 382,
#   'timestamp': 10000,
#   'x1': 1240.223695,
#   'y1': 360.852841,
#   'x2': 1278.612295,
#   'y2': 480.625275,
#   'trafficLightColor': 'none'},
#  {'id': 390,
#   'timestamp': 10000,
#   'x1': 740.746179,
#   'y1': 375.879131,
#   'x2': 764.238624,
#   'y2': 439.015079,
#   'trafficLightColor': 'none'},
#  {'id': 391,
#   'timestamp': 10000,
#   'x1': 790.667627,
#   'y1': 370.006019,
#   'x2': 815.628353,
#   'y2': 433.141966,
#   'trafficLightColor': 'none'},
#  {'id': 408,
#   'timestamp': 10000,
#   'x1': 324.341136,
#   'y1': 294.669551,
#   'x2': 338.665352,
#   'y2': 323.317979,
#   'trafficLightColor': 'none'},
#  {'id': 426,
#   'timestamp': 10000,
#   'x1': 824.931723,
#   'y1': 378.527296,
#   'x2': 860.93172,
#   'y2': 457.277287,
#   'trafficLightColor': 'none'},
#  {'id': 431,
#   'timestamp': 10000,
#   'x1': 1253.55667,
#   'y1': 345.902301,
#   'x2': 1278.306667,
#   'y2': 441.527291,
#   'trafficLightColor': 'none'},
#  {'id': 432,
#   'timestamp': 10000,
#   'x1': 1006.937512,
#   'y1': 371.830705,
#   'x2': 1025.653823,
#   'y2': 419.245358,
#   'trafficLightColor': 'none'},
#  {'id': 435,
#   'timestamp': 10000,
#   'x1': 823.731954,
#   'y1': 362.778053,
#   'x2': 857.407554,
#   'y2': 422.475708,
#   'trafficLightColor': 'none'},
#  {'id': 436,
#   'timestamp': 10000,
#   'x1': 878.837483,
#   'y1': 358.185925,
#   'x2': 906.390247,
#   'y2': 425.537126,
#   'trafficLightColor': 'none'},
#  {'id': 437,
#   'timestamp': 10000,
#   'x1': 923.228047,
#   'y1': 352.06309,
#   'x2': 949.250101,
#   'y2': 425.537126,
#   'trafficLightColor': 'none'},
#  {'id': 438,
#   'timestamp': 10000,
#   'x1': 970.680027,
#   'y1': 340.837886,
#   'x2': 1008.947754,
#   'y2': 450.028471,
#   'trafficLightColor': 'none'},
#  {'id': 439,
#   'timestamp': 10000,
#   'x1': 1041.092646,
#   'y1': 361.247346,
#   'x2': 1080.891082,
#   'y2': 448.497764,
#   'trafficLightColor': 'none'},
#  {'id': 440,
#   'timestamp': 10000,
#   'x1': 1013.539883,
#   'y1': 344.409543,
#   'x2': 1034.96981,
#   'y2': 422.475706,
#   'trafficLightColor': 'none'},
#  {'id': 441,
#   'timestamp': 10000,
#   'x1': 1030.377681,
#   'y1': 355.124508,
#   'x2': 1051.80761,
#   'y2': 431.659961,
#   'trafficLightColor': 'none'},
#  {'id': 460,
#   'timestamp': 10000,
#   'x1': 697.493103,
#   'y1': 356.144978,
#   'x2': 718.92303,
#   'y2': 405.127666,
#   'trafficLightColor': 'none'},
#  {'id': 461,
#   'timestamp': 10000,
#   'x1': 686.778139,
#   'y1': 356.655217,
#   'x2': 703.615939,
#   'y2': 391.861526,
#   'trafficLightColor': 'none'},
#  {'id': 462,
#   'timestamp': 10000,
#   'x1': 723.515159,
#   'y1': 356.144978,
#   'x2': 744.945086,
#   'y2': 397.474122,
#   'trafficLightColor': 'none'},
#  {'id': 463,
#   'timestamp': 10000,
#   'x1': 746.475793,
#   'y1': 353.083558,
#   'x2': 765.565011,
#   'y2': 399.515071,
#   'trafficLightColor': 'none'},
#  {'id': 465,
#   'timestamp': 10000,
#   'x1': 762.503593,
#   'y1': 358.185926,
#   'x2': 776.279973,
#   'y2': 397.984362,
#   'trafficLightColor': 'none'},
#  {'id': 516,
#   'timestamp': 10000,
#   'x1': 394.290278,
#   'y1': 361.848671,
#   'x2': 401.776795,
#   'y2': 378.069476,
#   'trafficLightColor': 'none'},
#  {'id': 610,
#   'timestamp': 10000,
#   'x1': 1005.963919,
#   'y1': 329.491759,
#   'x2': 1014.950058,
#   'y2': 360.943245,
#   'trafficLightColor': 'none'},
#  {'id': 611,
#   'timestamp': 10000,
#   'x1': 996.977779,
#   'y1': 330.989448,
#   'x2': 1002.968538,
#   'y2': 357.947864,
#   'trafficLightColor': 'none'},
#  {'id': 612,
#   'timestamp': 10000,
#   'x1': 1074.857649,
#   'y1': 314.514861,
#   'x2': 1095.825306,
#   'y2': 363.938625,
#   'trafficLightColor': 'none'},
#  {'id': 613,
#   'timestamp': 10000,
#   'x1': 1136.262931,
#   'y1': 307.026411,
#   'x2': 1155.7329,
#   'y2': 344.468656,
#   'trafficLightColor': 'none'},
#  {'id': 623,
#   'timestamp': 10000,
#   'x1': 195.981891,
#   'y1': 293.962293,
#   'x2': 222.981873,
#   'y2': 380.024735,
#   'trafficLightColor': 'none'},
#  {'id': 624,
#   'timestamp': 10000,
#   'x1': 136.919432,
#   'y1': 288.899797,
#   'x2': 168.98191,
#   'y2': 374.962238,
#   'trafficLightColor': 'none'},
#  {'id': 625,
#   'timestamp': 10000,
#   'x1': 116.669447,
#   'y1': 287.212297,
#   'x2': 138.60693,
#   'y2': 368.212241,
#   'trafficLightColor': 'none'},
#  {'id': 626,
#   'timestamp': 10000,
#   'x1': 354.606782,
#   'y1': 307.462285,
#   'x2': 371.481771,
#   'y2': 334.462266,
#   'trafficLightColor': 'none'},
#  {'id': 627,
#   'timestamp': 10000,
#   'x1': 386.669261,
#   'y1': 307.462285,
#   'x2': 398.481752,
#   'y2': 339.524763,
#   'trafficLightColor': 'none'},
#  {'id': 628,
#   'timestamp': 10000,
#   'x1': 401.856751,
#   'y1': 300.712288,
#   'x2': 422.106737,
#   'y2': 339.524763,
#   'trafficLightColor': 'none'},
#  {'id': 629,
#   'timestamp': 10000,
#   'x1': 1124.106254,
#   'y1': 305.774785,
#   'x2': 1184.856213,
#   'y2': 447.524686,
#   'trafficLightColor': 'none'},
#  {'id': 670,
#   'timestamp': 10000,
#   'x1': 106.544453,
#   'y1': 344.587258,
#   'x2': 131.856935,
#   'y2': 412.087213,
#   'trafficLightColor': 'none'},
#  {'id': 671,
#   'timestamp': 10000,
#   'x1': 82.919469,
#   'y1': 341.21226,
#   'x2': 106.544453,
#   'y2': 412.087213,
#   'trafficLightColor': 'none'},
#  {'id': 672,
#   'timestamp': 10000,
#   'x1': 246.606857,
#   'y1': 327.71227,
#   'x2': 276.981836,
#   'y2': 400.274721,
#   'trafficLightColor': 'none'},
#  {'id': 673,
#   'timestamp': 10000,
#   'x1': 39.044499,
#   'y1': 347.962256,
#   'x2': 64.356982,
#   'y2': 412.087212,
#   'trafficLightColor': 'none'},
#  {'id': 674,
#   'timestamp': 10000,
#   'x1': 229.731868,
#   'y1': 332.774766,
#   'x2': 248.294355,
#   'y2': 396.899721,
#   'trafficLightColor': 'none'},
#  {'id': 675,
#   'timestamp': 10000,
#   'x1': 266.856843,
#   'y1': 334.462265,
#   'x2': 287.106828,
#   'y2': 395.212222,
#   'trafficLightColor': 'none'},
#  {'id': 676,
#   'timestamp': 10000,
#   'x1': 847.356444,
#   'y1': 327.71227,
#   'x2': 860.856434,
#   'y2': 359.774749,
#   'trafficLightColor': 'none'},
#  {'id': 677,
#   'timestamp': 10000,
#   'x1': 989.106346,
#   'y1': 342.899759,
#   'x2': 1019.481325,
#   'y2': 385.08723,
#   'trafficLightColor': 'none'},
#  {'id': 678,
#   'timestamp': 10000,
#   'x1': 3.607024,
#   'y1': 341.21226,
#   'x2': 33.982003,
#   'y2': 422.212205,
#   'trafficLightColor': 'none'},
#  {'id': 679,
#   'timestamp': 10000,
#   'x1': 0,
#   'y1': 347.962256,
#   'x2': 13.732018,
#   'y2': 410.399712,
#   'trafficLightColor': 'none'},
#  {'id': 728,
#   'timestamp': 10000,
#   'x1': 536.184128,
#   'y1': 297.871006,
#   'x2': 550.293806,
#   'y2': 332.361334,
#   'trafficLightColor': 'none'},
#  {'id': 729,
#   'timestamp': 10000,
#   'x1': 760.371252,
#   'y1': 304.141975,
#   'x2': 785.455129,
#   'y2': 376.258113,
#   'trafficLightColor': 'none'},
#  {'id': 730,
#   'timestamp': 10000,
#   'x1': 785.455127,
#   'y1': 297.871006,
#   'x2': 816.809969,
#   'y2': 379.393597,
#   'trafficLightColor': 'none'},
#  {'id': 773,
#   'timestamp': 10000,
#   'x1': 853.463765,
#   'y1': 257.037333,
#   'x2': 870.932322,
#   'y2': 290.726692,
#   'trafficLightColor': 'none'},
#  {'id': 774,
#   'timestamp': 10000,
#   'x1': 781.09403,
#   'y1': 258.285087,
#   'x2': 797.314833,
#   'y2': 311.93851,
#   'trafficLightColor': 'none'},
#  {'id': 775,
#   'timestamp': 10000,
#   'x1': 766.120982,
#   'y1': 260.780595,
#   'x2': 782.341786,
#   'y2': 309.443003,
#   'trafficLightColor': 'none'},
#  {'id': 863,
#   'timestamp': 10000,
#   'x1': 679.191746,
#   'y1': 248.216903,
#   'x2': 692.371404,
#   'y2': 271.281303,
#   'trafficLightColor': 'none'},
#  {'id': 864,
#   'timestamp': 10000,
#   'x1': 696.764624,
#   'y1': 242.725379,
#   'x2': 703.354452,
#   'y2': 270.183,
#   'trafficLightColor': 'none'},
#  {'id': 865,
#   'timestamp': 10000,
#   'x1': 700.059537,
#   'y1': 243.823683,
#   'x2': 713.239196,
#   'y2': 275.674526,
#   'trafficLightColor': 'none'},
#  {'id': 866,
#   'timestamp': 10000,
#   'x1': 686.879882,
#   'y1': 242.725379,
#   'x2': 700.05954,
#   'y2': 276.772829,
#   'trafficLightColor': 'none'},
#  {'id': 867,
#   'timestamp': 10000,
#   'x1': 747.286649,
#   'y1': 237.233852,
#   'x2': 767.056136,
#   'y2': 267.98639,
#   'trafficLightColor': 'none'},
#  {'id': 910,
#   'timestamp': 10000,
#   'x1': 14.872971,
#   'y1': 296.20129,
#   'x2': 43.630378,
#   'y2': 353.716104,
#   'trafficLightColor': 'none'},
#  {'id': 911,
#   'timestamp': 10000,
#   'x1': 868.967954,
#   'y1': 322.082956,
#   'x2': 896.287491,
#   'y2': 385.349253,
#   'trafficLightColor': 'none'},
#  {'id': 912,
#   'timestamp': 10000,
#   'x1': 867.530084,
#   'y1': 330.710179,
#   'x2': 896.287491,
#   'y2': 388.224992,
#   'trafficLightColor': 'none'},
#  {'id': 999,
#   'timestamp': 10000,
#   'x1': 696.599756,
#   'y1': 332.292736,
#   'x2': 708.749752,
#   'y2': 366.428441,
#   'trafficLightColor': 'none'},
#  {'id': 1000,
#   'timestamp': 10000,
#   'x1': 742.499739,
#   'y1': 339.428451,
#   'x2': 753.299734,
#   'y2': 378.578439,
#   'trafficLightColor': 'none'},
#  {'id': 1148,
#   'timestamp': 10000,
#   'x1': 964.057881,
#   'y1': 255.637162,
#   'x2': 993.748607,
#   'y2': 325.410372,
#   'trafficLightColor': 'none'},
#  {'id': 1164,
#   'timestamp': 10000,
#   'x1': 987.99164,
#   'y1': 353.954018,
#   'x2': 1010.456987,
#   'y2': 406.373162,
#   'trafficLightColor': 'none'},
#  {'id': 1190,
#   'timestamp': 10000,
#   'x1': 149.66901,
#   'y1': 395.904586,
#   'x2': 204.584254,
#   'y2': 544.175744,
#   'trafficLightColor': 'none'},
#  {'id': 1191,
#   'timestamp': 10000,
#   'x1': 258.401193,
#   'y1': 381.626622,
#   'x2': 291.350339,
#   'y2': 496.948634,
#   'trafficLightColor': 'none'},
#  {'id': 1238,
#   'timestamp': 10000,
#   'x1': 956.293459,
#   'y1': 294.818531,
#   'x2': 974.317299,
#   'y2': 334.728463,
#   'trafficLightColor': 'none'},
#  {'id': 1239,
#   'timestamp': 10000,
#   'x1': 222.46567,
#   'y1': 306.405287,
#   'x2': 245.639179,
#   'y2': 356.614555,
#   'trafficLightColor': 'none'},
#  {'id': 1383,
#   'timestamp': 10000,
#   'x1': 993.486305,
#   'y1': 172.657896,
#   'x2': 1010.112621,
#   'y2': 235.326318,
#   'trafficLightColor': 'none'},
#  {'id': 1384,
#   'timestamp': 10000,
#   'x1': 976.85999,
#   'y1': 172.657896,
#   'x2': 996.0442,
#   'y2': 243.000002,
#   'trafficLightColor': 'none'},
#  {'id': 1385,
#   'timestamp': 10000,
#   'x1': 947.444201,
#   'y1': 175.215789,
#   'x2': 971.744201,
#   'y2': 243,
#   'trafficLightColor': 'none'},
#  {'id': 1443,
#   'timestamp': 10000,
#   'x1': 638.382143,
#   'y1': 155.256246,
#   'x2': 662.08947,
#   'y2': 196.432129,
#   'trafficLightColor': 'none'},
#  {'id': 1444,
#   'timestamp': 10000,
#   'x1': 904.153754,
#   'y1': 151.512984,
#   'x2': 912.888032,
#   'y2': 183.954589,
#   'trafficLightColor': 'none'},
#  {'id': 1563,
#   'timestamp': 10000,
#   'x1': 838.962497,
#   'y1': 438.302481,
#   'x2': 850.56462,
#   'y2': 464.084979,
#   'trafficLightColor': 'none'},
#  {'id': 1690,
#   'timestamp': 10000,
#   'x1': 945.381671,
#   'y1': 436.298001,
#   'x2': 969.088999,
#   'y2': 489.951425,
#   'trafficLightColor': 'none'},
#  {'id': 1691,
#   'timestamp': 10000,
#   'x1': 909.196805,
#   'y1': 428.811478,
#   'x2': 941.63841,
#   'y2': 496.190196,
#   'trafficLightColor': 'none'},
#  {'id': 1693,
#   'timestamp': 10000,
#   'x1': 847.640926,
#   'y1': 437.96167,
#   'x2': 865.109483,
#   'y2': 492.862846,
#   'trafficLightColor': 'none'},
#  {'id': 1694,
#   'timestamp': 10000,
#   'x1': 866.357236,
#   'y1': 435.466162,
#   'x2': 887.569055,
#   'y2': 491.615091,
#   'trafficLightColor': 'none'},
#  {'id': 1695,
#   'timestamp': 10000,
#   'x1': 892.560072,
#   'y1': 431.722899,
#   'x2': 907.533122,
#   'y2': 456.677981,
#   'trafficLightColor': 'none'},
#  {'id': 1696,
#   'timestamp': 10000,
#   'x1': 999.035095,
#   'y1': 430.475147,
#   'x2': 1027.733438,
#   'y2': 489.119586,
#   'trafficLightColor': 'none'},
#  {'id': 1697,
#   'timestamp': 10000,
#   'x1': 729.520221,
#   'y1': 420.909042,
#   'x2': 744.493273,
#   'y2': 439.625353,
#   'trafficLightColor': 'none'},
#  {'id': 1698,
#   'timestamp': 10000,
#   'x1': 301.956479,
#   'y1': 442.120862,
#   'x2': 316.929529,
#   'y2': 480.801236,
#   'trafficLightColor': 'none'},
#  {'id': 1699,
#   'timestamp': 10000,
#   'x1': 328.159314,
#   'y1': 438.377601,
#   'x2': 338.141347,
#   'y2': 452.102894,
#   'trafficLightColor': 'none'},
#  {'id': 1700,
#   'timestamp': 10000,
#   'x1': 340.636855,
#   'y1': 438.377601,
#   'x2': 348.12338,
#   'y2': 453.350648,
#   'trafficLightColor': 'none'},
#  {'id': 1701,
#   'timestamp': 10000,
#   'x1': 293.2222,
#   'y1': 447.111877,
#   'x2': 303.204232,
#   'y2': 464.580433,
#   'trafficLightColor': 'none'},
#  {'id': 1702,
#   'timestamp': 10000,
#   'x1': 286.983431,
#   'y1': 444.616371,
#   'x2': 293.2222,
#   'y2': 460.837172,
#   'trafficLightColor': 'none'},
#  {'id': 1703,
#   'timestamp': 10000,
#   'x1': 279.496907,
#   'y1': 443.368616,
#   'x2': 288.231185,
#   'y2': 462.084927,
#   'trafficLightColor': 'none'},
#  {'id': 1704,
#   'timestamp': 10000,
#   'x1': 259.532842,
#   'y1': 444.616371,
#   'x2': 273.258137,
#   'y2': 460.837172,
#   'trafficLightColor': 'none'},
#  {'id': 1705,
#   'timestamp': 10000,
#   'x1': 243.312038,
#   'y1': 447.111877,
#   'x2': 258.285088,
#   'y2': 462.084928,
#   'trafficLightColor': 'none'},
#  {'id': 1706,
#   'timestamp': 10000,
#   'x1': 224.595729,
#   'y1': 445.864124,
#   'x2': 237.07327,
#   'y2': 460.837171,
#   'trafficLightColor': 'none'},
#  {'id': 1707,
#   'timestamp': 10000,
#   'x1': 232.082252,
#   'y1': 444.616371,
#   'x2': 243.312038,
#   'y2': 462.084927,
#   'trafficLightColor': 'none'},
#  {'id': 1708,
#   'timestamp': 10000,
#   'x1': 215.86145,
#   'y1': 447.111877,
#   'x2': 224.595729,
#   'y2': 463.332679,
#   'trafficLightColor': 'none'},
#  {'id': 1709,
#   'timestamp': 10000,
#   'x1': 199.640646,
#   'y1': 445.864124,
#   'x2': 212.118187,
#   'y2': 462.084927,
#   'trafficLightColor': 'none'},
#  {'id': 1710,
#   'timestamp': 10000,
#   'x1': 143.491716,
#   'y1': 439.625353,
#   'x2': 153.473748,
#   'y2': 477.057974,
#   'trafficLightColor': 'none'},
#  {'id': 1711,
#   'timestamp': 10000,
#   'x1': 152.225994,
#   'y1': 442.120862,
#   'x2': 162.208028,
#   'y2': 467.075944,
#   'trafficLightColor': 'none'},
#  {'id': 1719,
#   'timestamp': 10000,
#   'x1': 172.203043,
#   'y1': 439.209422,
#   'x2': 190.919354,
#   'y2': 469.15552,
#   'trafficLightColor': 'none'},
#  {'id': 1739,
#   'timestamp': 10000,
#   'x1': 707.476542,
#   'y1': 394.290278,
#   'x2': 724.9451,
#   'y2': 441.704931,
#   'trafficLightColor': 'none'},
#  {'id': 1797,
#   'timestamp': 10000,
#   'x1': 90.101235,
#   'y1': 444.284059,
#   'x2': 110.063307,
#   'y2': 494.957012,
#   'trafficLightColor': 'none'},
#  {'id': 1798,
#   'timestamp': 10000,
#   'x1': 199.124859,
#   'y1': 445.819603,
#   'x2': 217.551388,
#   'y2': 498.0281,
#   'trafficLightColor': 'none'},
#  {'id': 1799,
#   'timestamp': 10000,
#   'x1': 209.873668,
#   'y1': 442.748515,
#   'x2': 229.835741,
#   'y2': 490.35038,
#   'trafficLightColor': 'none'},
#  {'id': 1806,
#   'timestamp': 10000,
#   'x1': 1003.749917,
#   'y1': 399.753281,
#   'x2': 1029.854165,
#   'y2': 458.103955,
#   'trafficLightColor': 'none'},
#  {'id': 1868,
#   'timestamp': 10000,
#   'x1': 1002.606337,
#   'y1': 243.337328,
#   'x2': 1038.043811,
#   'y2': 310.837281,
#   'trafficLightColor': 'none'},
#  {'id': 1869,
#   'timestamp': 10000,
#   'x1': 867.60643,
#   'y1': 255.149819,
#   'x2': 887.856416,
#   'y2': 293.962293,
#   'trafficLightColor': 'none'},
#  {'id': 1870,
#   'timestamp': 10000,
#   'x1': 852.418941,
#   'y1': 246.712325,
#   'x2': 874.356425,
#   'y2': 283.837302,
#   'trafficLightColor': 'none'},
#  {'id': 1871,
#   'timestamp': 10000,
#   'x1': 951.981372,
#   'y1': 250.087323,
#   'x2': 985.731348,
#   'y2': 319.274776,
#   'trafficLightColor': 'none'},
#  {'id': 1872,
#   'timestamp': 10000,
#   'x1': 104.856955,
#   'y1': 246.712325,
#   'x2': 147.044425,
#   'y2': 361.462247,
#   'trafficLightColor': 'none'},
#  {'id': 1887,
#   'timestamp': 10000,
#   'x1': 420.419238,
#   'y1': 248.399824,
#   'x2': 444.04422,
#   'y2': 282.149801,
#   'trafficLightColor': 'none'},
#  {'id': 1888,
#   'timestamp': 10000,
#   'x1': 162.231914,
#   'y1': 252.449826,
#   'x2': 189.231895,
#   'y2': 318.262282,
#   'trafficLightColor': 'none'},
#  {'id': 1889,
#   'timestamp': 10000,
#   'x1': 136.919433,
#   'y1': 250.762329,
#   'x2': 157.169418,
#   'y2': 330.074775,
#   'trafficLightColor': 'none'},
#  {'id': 1919,
#   'timestamp': 10000,
#   'x1': 456.67798,
#   'y1': 303.204232,
#   'x2': 485.376323,
#   'y2': 364.34418,
#   'trafficLightColor': 'none'},
#  {'id': 2009,
#   'timestamp': 10000,
#   'x1': 417.008887,
#   'y1': 300.456327,
#   'x2': 436.908106,
#   'y2': 344.846892,
#   'trafficLightColor': 'none'},
#  {'id': 2123,
#   'timestamp': 10000,
#   'x1': 1117.380175,
#   'y1': 339.867064,
#   'x2': 1149.626599,
#   'y2': 419.715352,
#   'trafficLightColor': 'none'},
#  {'id': 2272,
#   'timestamp': 10000,
#   'x1': 341.992155,
#   'y1': 334.655964,
#   'x2': 355.977778,
#   'y2': 364.375413,
#   'trafficLightColor': 'none'},
#  {'id': 2273,
#   'timestamp': 10000,
#   'x1': 326.25833,
#   'y1': 336.404167,
#   'x2': 338.49575,
#   'y2': 380.109238,
#   'trafficLightColor': 'none'},
#  {'id': 2274,
#   'timestamp': 10000,
#   'x1': 355.977778,
#   'y1': 324.166747,
#   'x2': 371.711604,
#   'y2': 367.871818,
#   'trafficLightColor': 'none'},
#  {'id': 2296,
#   'timestamp': 10000,
#   'x1': 59.994566,
#   'y1': 379.398972,
#   'x2': 100.284722,
#   'y2': 446.549232,
#   'trafficLightColor': 'none'},
#  {'id': 2416,
#   'timestamp': 10000,
#   'x1': 631.898477,
#   'y1': 366.58213,
#   'x2': 641.619991,
#   'y2': 390.885918,
#   'trafficLightColor': 'none'},
#  {'id': 2424,
#   'timestamp': 10000,
#   'x1': 471.493481,
#   'y1': 377.518831,
#   'x2': 484.860563,
#   'y2': 420.050461,
#   'trafficLightColor': 'none'},
#  {'id': 2425,
#   'timestamp': 10000,
#   'x1': 549.265599,
#   'y1': 365.366939,
#   'x2': 562.632685,
#   'y2': 417.620081,
#   'trafficLightColor': 'none'},
#  {'id': 2703,
#   'timestamp': 10000,
#   'x1': 168.749941,
#   'y1': 328.049885,
#   'x2': 330.749884,
#   'y2': 641.249776,
#   'trafficLightColor': 'none'},
#  {'id': 2922,
#   'timestamp': 10000,
#   'x1': 1039.437485,
#   'y1': 417.988881,
#   'x2': 1065.866489,
#   'y2': 489.44507,
#   'trafficLightColor': 'none'},
#  {'id': 2923,
#   'timestamp': 10000,
#   'x1': 1137.322675,
#   'y1': 426.798548,
#   'x2': 1169.624786,
#   'y2': 534.472257,
#   'trafficLightColor': 'none'},
#  {'id': 2924,
#   'timestamp': 10000,
#   'x1': 1172.561343,
#   'y1': 428.756252,
#   'x2': 1201.926902,
#   'y2': 520.76833,
#   'trafficLightColor': 'none'},
#  {'id': 3021,
#   'timestamp': 10000,
#   'x1': 626.179459,
#   'y1': 489.636631,
#   'x2': 639.403948,
#   'y2': 525.342746,
#   'trafficLightColor': 'none'},
#  {'id': 3022,
#   'timestamp': 10000,
#   'x1': 659.901901,
#   'y1': 481.371326,
#   'x2': 678.416183,
#   'y2': 526.334582,
#   'trafficLightColor': 'none'},
#  {'id': 3023,
#   'timestamp': 10000,
#   'x1': 645.354965,
#   'y1': 490.628467,
#   'x2': 655.934554,
#   'y2': 526.334582,
#   'trafficLightColor': 'none'},
#  {'id': 3064,
#   'timestamp': 10000,
#   'x1': 366.934003,
#   'y1': 428.339287,
#   'x2': 374.422452,
#   'y2': 452.302325,
#   'trafficLightColor': 'none'},
#  {'id': 3065,
#   'timestamp': 10000,
#   'x1': 417.85546,
#   'y1': 416.357769,
#   'x2': 426.841598,
#   'y2': 441.818495,
#   'trafficLightColor': 'none'},
#  {'id': 3066,
#   'timestamp': 10000,
#   'x1': 440.320808,
#   'y1': 423.846218,
#   'x2': 446.311566,
#   'y2': 449.306943,
#   'trafficLightColor': 'none'},
#  {'id': 3067,
#   'timestamp': 10000,
#   'x1': 375.920145,
#   'y1': 405.873939,
#   'x2': 390.89704,
#   'y2': 450.804634,
#   'trafficLightColor': 'none'},
#  {'id': 3078,
#   'timestamp': 10000,
#   'x1': 364.023778,
#   'y1': 426.917938,
#   'x2': 377.364963,
#   'y2': 451.694426,
#   'trafficLightColor': 'none'},
#  {'id': 3210,
#   'timestamp': 10000,
#   'x1': 781.094031,
#   'y1': 326.911558,
#   'x2': 801.058093,
#   'y2': 373.078458,
#   'trafficLightColor': 'none'},
#  {'id': 3243,
#   'timestamp': 10000,
#   'x1': 88.590537,
#   'y1': 326.911559,
#   'x2': 112.297864,
#   'y2': 385.555999,
#   'trafficLightColor': 'none'},
#  {'id': 3291,
#   'timestamp': 10000,
#   'x1': 194.088777,
#   'y1': 330.655609,
#   'x2': 228.480607,
#   'y2': 383.309055,
#   'trafficLightColor': 'none'},
#  {'id': 3292,
#   'timestamp': 10000,
#   'x1': 1080.096729,
#   'y1': 365.79775,
#   'x2': 1092.077004,
#   'y2': 399.342523,
#   'trafficLightColor': 'none'},
#  {'id': 3293,
#   'timestamp': 10000,
#   'x1': 1040.162476,
#   'y1': 363.401695,
#   'x2': 1059.330917,
#   'y2': 389.758304,
#   'trafficLightColor': 'none'},
#  {'id': 3294,
#   'timestamp': 10000,
#   'x1': 1139.199423,
#   'y1': 360.206955,
#   'x2': 1172.744193,
#   'y2': 404.134632,
#   'trafficLightColor': 'none'},
#  {'id': 3295,
#   'timestamp': 10000,
#   'x1': 1060.129603,
#   'y1': 364.20038,
#   'x2': 1082.492785,
#   'y2': 418.510964,
#   'trafficLightColor': 'none'},
#  {'id': 3297,
#   'timestamp': 10000,
#   'x1': 621.696434,
#   'y1': 350.622734,
#   'x2': 627.287229,
#   'y2': 365.79775,
#   'trafficLightColor': 'none'},
#  {'id': 3298,
#   'timestamp': 10000,
#   'x1': 572.177967,
#   'y1': 348.22668,
#   'x2': 579.366133,
#   'y2': 365.79775,
#   'trafficLightColor': 'none'},
#  {'id': 3316,
#   'timestamp': 10000,
#   'x1': 167.124847,
#   'y1': 325.464156,
#   'x2': 183.897235,
#   'y2': 362.203665,
#   'trafficLightColor': 'none'},
#  {'id': 3317,
#   'timestamp': 10000,
#   'x1': 577.648959,
#   'y1': 343.035227,
#   'x2': 592.823975,
#   'y2': 361.404983,
#   'trafficLightColor': 'none'},
#  {'id': 3425,
#   'timestamp': 10000,
#   'x1': 215.861449,
#   'y1': 351.86664,
#   'x2': 233.330006,
#   'y2': 422.98862,
#   'trafficLightColor': 'none'},
#  {'id': 3426,
#   'timestamp': 10000,
#   'x1': 242.064284,
#   'y1': 356.857656,
#   'x2': 273.258135,
#   'y2': 424.236376,
#   'trafficLightColor': 'none'},
#  {'id': 3439,
#   'timestamp': 10000,
#   'x1': 831.004192,
#   'y1': 370.582951,
#   'x2': 842.233979,
#   'y2': 413.006588,
#   'trafficLightColor': 'none'},
#  {'id': 3464,
#   'timestamp': 10000,
#   'x1': 777.35077,
#   'y1': 379.317229,
#   'x2': 787.332802,
#   'y2': 403.024554,
#   'trafficLightColor': 'none'},
#  {'id': 3575,
#   'timestamp': 10000,
#   'x1': 1060.761781,
#   'y1': 384.749735,
#   'x2': 1077.636769,
#   'y2': 408.374719,
#   'trafficLightColor': 'none'},
#  {'id': 3627,
#   'timestamp': 10000,
#   'x1': 911.924363,
#   'y1': 420.524706,
#   'x2': 923.736855,
#   'y2': 440.774693,
#   'trafficLightColor': 'none'},
#  {'id': 3805,
#   'timestamp': 10000,
#   'x1': 69.690629,
#   'y1': 273.260627,
#   'x2': 100.868015,
#   'y2': 359.456928,
#   'trafficLightColor': 'none'},
#  {'id': 3806,
#   'timestamp': 10000,
#   'x1': 205.403958,
#   'y1': 286.098369,
#   'x2': 229.245492,
#   'y2': 357.622964,
#   'trafficLightColor': 'none'},
#  {'id': 3807,
#   'timestamp': 10000,
#   'x1': 95.366122,
#   'y1': 291.600261,
#   'x2': 115.539729,
#   'y2': 348.453141,
#   'trafficLightColor': 'none'},
#  {'id': 3808,
#   'timestamp': 10000,
#   'x1': 110.037835,
#   'y1': 286.098369,
#   'x2': 139.381256,
#   'y2': 337.449362,
#   'trafficLightColor': 'none'},
#  {'id': 3842,
#   'timestamp': 10000,
#   'x1': 243.642279,
#   'y1': 301.559818,
#   'x2': 256.553096,
#   'y2': 334.759064,
#   'trafficLightColor': 'none'},
#  {'id': 3843,
#   'timestamp': 10000,
#   'x1': 189.232405,
#   'y1': 305.248623,
#   'x2': 203.987624,
#   'y2': 336.603466,
#   'trafficLightColor': 'none'},
#  {'id': 3844,
#   'timestamp': 10000,
#   'x1': 850.977702,
#   'y1': 293.260007,
#   'x2': 875.877136,
#   'y2': 343.981076,
#   'trafficLightColor': 'none'},
#  {'id': 3940,
#   'timestamp': 10000,
#   'x1': 82.351767,
#   'y1': 207.127171,
#   'x2': 111.05011,
#   'y2': 230.834498,
#   'trafficLightColor': 'none'},
#  {'id': 3941,
#   'timestamp': 10000,
#   'x1': 957.859211,
#   'y1': 234.993681,
#   'x2': 1056.110973,
#   'y2': 388.738851,
#   'trafficLightColor': 'none'},
#  {'id': 3942,
#   'timestamp': 10000,
#   'x1': 805.633219,
#   'y1': 239.984697,
#   'x2': 820.606265,
#   'y2': 292.390367,
#   'trafficLightColor': 'none'},
#  {'id': 3943,
#   'timestamp': 10000,
#   'x1': 788.164662,
#   'y1': 239.984697,
#   'x2': 805.633219,
#   'y2': 298.62914,
#   'trafficLightColor': 'none'},
#  {'id': 3944,
#   'timestamp': 10000,
#   'x1': 633.443161,
#   'y1': 239.984697,
#   'x2': 649.663964,
#   'y2': 269.930796,
#   'trafficLightColor': 'none'},
#  {'id': 3945,
#   'timestamp': 10000,
#   'x1': 734.511239,
#   'y1': 227.507157,
#   'x2': 768.200598,
#   'y2': 304.867908,
#   'trafficLightColor': 'none'},
#  {'id': 3947,
#   'timestamp': 10000,
#   'x1': 319.425035,
#   'y1': 257.453254,
#   'x2': 331.902575,
#   'y2': 281.160581,
#   'trafficLightColor': 'none'},
#  {'id': 3981,
#   'timestamp': 10000,
#   'x1': 150.97824,
#   'y1': 234.577761,
#   'x2': 208.374925,
#   'y2': 330.074774,
#   'trafficLightColor': 'none'},
#  {'id': 3982,
#   'timestamp': 10000,
#   'x1': 237.073268,
#   'y1': 229.586743,
#   'x2': 273.258135,
#   'y2': 295.717707,
#   'trafficLightColor': 'none'},
#  {'id': 3983,
#   'timestamp': 10000,
#   'x1': 12.47754,
#   'y1': 237.073268,
#   'x2': 39.928129,
#   'y2': 314.43402,
#   'trafficLightColor': 'none'},
#  {'id': 3984,
#   'timestamp': 10000,
#   'x1': 29.946096,
#   'y1': 233.330006,
#   'x2': 87.342782,
#   'y2': 310.690757,
#   'trafficLightColor': 'none'},
#  {'id': 3985,
#   'timestamp': 10000,
#   'x1': 62.387701,
#   'y1': 242.064284,
#   'x2': 81.104012,
#   'y2': 310.690757,
#   'trafficLightColor': 'none'},
#  {'id': 3986,
#   'timestamp': 10000,
#   'x1': 77.360752,
#   'y1': 237.073268,
#   'x2': 96.077061,
#   'y2': 298.213215,
#   'trafficLightColor': 'none'},
#  {'id': 3987,
#   'timestamp': 10000,
#   'x1': 103.169455,
#   'y1': 223.762346,
#   'x2': 124.775404,
#   'y2': 278.249151,
#   'trafficLightColor': 'none'},
#  {'id': 3988,
#   'timestamp': 10000,
#   'x1': 0,
#   'y1': 227.091236,
#   'x2': 17.468558,
#   'y2': 314.43402,
#   'trafficLightColor': 'none'},
#  {'id': 3989,
#   'timestamp': 10000,
#   'x1': 137.252944,
#   'y1': 237.073268,
#   'x2': 157.217009,
#   'y2': 293.2222,
#   'trafficLightColor': 'none'},
#  {'id': 3990,
#   'timestamp': 10000,
#   'x1': 326.911558,
#   'y1': 232.082252,
#   'x2': 370.58295,
#   'y2': 306.947495,
#   'trafficLightColor': 'none'},
#  {'id': 3991,
#   'timestamp': 10000,
#   'x1': 384.308245,
#   'y1': 242.064284,
#   'x2': 396.785786,
#   'y2': 286.983429,
#   'trafficLightColor': 'none'},
#  {'id': 3992,
#   'timestamp': 10000,
#   'x1': 366.839689,
#   'y1': 240.81653,
#   'x2': 381.812737,
#   'y2': 267.019366,
#   'trafficLightColor': 'none'},
#  {'id': 3993,
#   'timestamp': 10000,
#   'x1': 298.213215,
#   'y1': 233.330006,
#   'x2': 326.911558,
#   'y2': 281.992413,
#   'trafficLightColor': 'none'},
#  {'id': 3994,
#   'timestamp': 10000,
#   'x1': 408.015572,
#   'y1': 239.568777,
#   'x2': 421.740866,
#   'y2': 264.523857,
#   'trafficLightColor': 'none'},
#  {'id': 3995,
#   'timestamp': 10000,
#   'x1': 422.98862,
#   'y1': 242.064284,
#   'x2': 436.713915,
#   'y2': 264.523857,
#   'trafficLightColor': 'none'},
#  {'id': 3996,
#   'timestamp': 10000,
#   'x1': 434.218406,
#   'y1': 240.81653,
#   'x2': 446.695946,
#   'y2': 267.019366,
#   'trafficLightColor': 'none'},
#  {'id': 3997,
#   'timestamp': 10000,
#   'x1': 446.695946,
#   'y1': 244.559792,
#   'x2': 456.67798,
#   'y2': 262.02835,
#   'trafficLightColor': 'none'},
#  {'id': 4000,
#   'timestamp': 10000,
#   'x1': 777.350769,
#   'y1': 252.046317,
#   'x2': 793.356481,
#   'y2': 278.249152,
#   'trafficLightColor': 'none'},
#  {'id': 4001,
#   'timestamp': 10000,
#   'x1': 806.049111,
#   'y1': 248.303055,
#   'x2': 821.022159,
#   'y2': 277.762309,
#   'trafficLightColor': 'none'},
#  {'id': 4002,
#   'timestamp': 10000,
#   'x1': 826.013176,
#   'y1': 242.064284,
#   'x2': 848.472749,
#   'y2': 279.496906,
#   'trafficLightColor': 'none'},
#  {'id': 4028,
#   'timestamp': 10000,
#   'x1': 1137.606244,
#   'y1': 386.774729,
#   'x2': 1189.918708,
#   'y2': 494.774656,
#   'trafficLightColor': 'none'},
#  {'id': 4036,
#   'timestamp': 10000,
#   'x1': 725.856527,
#   'y1': 422.212206,
#   'x2': 739.356518,
#   'y2': 449.212187,
#   'trafficLightColor': 'none'},
#  {'id': 4068,
#   'timestamp': 10000,
#   'x1': 703.750574,
#   'y1': 453.413051,
#   'x2': 714.109368,
#   'y2': 471.54094,
#   'trafficLightColor': 'none'},
#  {'id': 4069,
#   'timestamp': 10000,
#   'x1': 712.382902,
#   'y1': 454.276283,
#   'x2': 721.878465,
#   'y2': 469.814474,
#   'trafficLightColor': 'none'},
#  {'id': 4117,
#   'timestamp': 10000,
#   'x1': 640.097824,
#   'y1': 358.10541,
#   'x2': 655.070872,
#   'y2': 381.812738,
#   'trafficLightColor': 'none'},
#  {'id': 4288,
#   'timestamp': 10000,
#   'x1': 717.879507,
#   'y1': 339.062406,
#   'x2': 753.025263,
#   'y2': 441.204759,
#   'trafficLightColor': 'none'},
#  {'id': 4329,
#   'timestamp': 10000,
#   'x1': 613.031213,
#   'y1': 316.363336,
#   'x2': 702.892536,
#   'y2': 522.295528,
#   'trafficLightColor': 'none'},
#  {'id': 4330,
#   'timestamp': 10000,
#   'x1': 724.60902,
#   'y1': 305.130671,
#   'x2': 829.447229,
#   'y2': 511.062863,
#   'trafficLightColor': 'none'},
#  {'id': 4335,
#   'timestamp': 10000,
#   'x1': 673.47678,
#   'y1': 357.947865,
#   'x2': 691.449055,
#   'y2': 398.38549,
#   'trafficLightColor': 'none'},
#  {'id': 4336,
#   'timestamp': 10000,
#   'x1': 706.425954,
#   'y1': 351.957106,
#   'x2': 718.407472,
#   'y2': 395.39011,
#   'trafficLightColor': 'none'},
#  {'id': 4337,
#   'timestamp': 10000,
#   'x1': 721.402852,
#   'y1': 353.454795,
#   'x2': 731.88668,
#   'y2': 393.89242,
#   'trafficLightColor': 'none'},
#  {'id': 4338,
#   'timestamp': 10000,
#   'x1': 731.886682,
#   'y1': 360.943245,
#   'x2': 742.370511,
#   'y2': 399.883179,
#   'trafficLightColor': 'none'},
#  {'id': 4339,
#   'timestamp': 10000,
#   'x1': 743.868201,
#   'y1': 357.947865,
#   'x2': 757.347408,
#   'y2': 398.38549,
#   'trafficLightColor': 'none'},
#  {'id': 4384,
#   'timestamp': 10000,
#   'x1': 339.3891,
#   'y1': 350.618886,
#   'x2': 354.362148,
#   'y2': 400.529048,
#   'trafficLightColor': 'none'},
#  {'id': 4385,
#   'timestamp': 10000,
#   'x1': 313.186265,
#   'y1': 351.86664,
#   'x2': 329.407067,
#   'y2': 391.794769,
#   'trafficLightColor': 'none'},
#  {'id': 4386,
#   'timestamp': 10000,
#   'x1': 299.46097,
#   'y1': 351.86664,
#   'x2': 310.690757,
#   'y2': 395.538032,
#   'trafficLightColor': 'none'},
#  {'id': 4387,
#   'timestamp': 10000,
#   'x1': 272.010381,
#   'y1': 351.86664,
#   'x2': 291.974446,
#   'y2': 406.767818,
#   'trafficLightColor': 'none'},
#  {'id': 4388,
#   'timestamp': 10000,
#   'x1': 232.082252,
#   'y1': 349.371132,
#   'x2': 262.028349,
#   'y2': 403.024556,
#   'trafficLightColor': 'none'},
#  {'id': 4389,
#   'timestamp': 10000,
#   'x1': 899.630665,
#   'y1': 358.10541,
#   'x2': 925.8335,
#   'y2': 413.006588,
#   'trafficLightColor': 'none'},
#  {'id': 4390,
#   'timestamp': 10000,
#   'x1': 872.180076,
#   'y1': 361.848672,
#   'x2': 895.887403,
#   'y2': 413.006588,
#   'trafficLightColor': 'none'},
#  {'id': 4391,
#   'timestamp': 10000,
#   'x1': 822.269914,
#   'y1': 361.848672,
#   'x2': 840.986225,
#   'y2': 385.555999,
#   'trafficLightColor': 'none'},
#  {'id': 4392,
#   'timestamp': 10000,
#   'x1': 773.607506,
#   'y1': 356.857656,
#   'x2': 793.571571,
#   'y2': 404.27231,
#   'trafficLightColor': 'none'},
#  {'id': 4393,
#   'timestamp': 10000,
#   'x1': 752.395688,
#   'y1': 355.609902,
#   'x2': 769.864244,
#   'y2': 401.776802,
#   'trafficLightColor': 'none'},
#  {'id': 4394,
#   'timestamp': 10000,
#   'x1': 734.927131,
#   'y1': 354.362148,
#   'x2': 751.147934,
#   'y2': 403.024556,
#   'trafficLightColor': 'none'},
#  {'id': 4395,
#   'timestamp': 10000,
#   'x1': 718.706329,
#   'y1': 363.096426,
#   'x2': 736.174885,
#   'y2': 399.281295,
#   'trafficLightColor': 'none'},
#  {'id': 4396,
#   'timestamp': 10000,
#   'x1': 709.97205,
#   'y1': 361.848672,
#   'x2': 722.449591,
#   'y2': 399.281295,
#   'trafficLightColor': 'none'},
#  {'id': 4397,
#   'timestamp': 10000,
#   'x1': 697.49451,
#   'y1': 358.10541,
#   'x2': 711.219804,
#   'y2': 393.042523,
#   'trafficLightColor': 'none'},
#  {'id': 4429,
#   'timestamp': 10000,
#   'x1': 121.731943,
#   'y1': 327.71227,
#   'x2': 160.544416,
#   'y2': 405.337217,
#   'trafficLightColor': 'none'},
#  {'id': 4430,
#   'timestamp': 10000,
#   'x1': 69.419477,
#   'y1': 314.212279,
#   'x2': 118.356945,
#   'y2': 410.399713,
#   'trafficLightColor': 'none'},
#  {'id': 4472,
#   'timestamp': 10000,
#   'x1': 359.353164,
#   'y1': 366.839689,
#   'x2': 432.970653,
#   'y2': 534.038731,
#   'trafficLightColor': 'none'},
#  {'id': 4542,
#   'timestamp': 10000,
#   'x1': 538.197923,
#   'y1': 264.939778,
#   'x2': 558.154664,
#   'y2': 327.994069,
#   'trafficLightColor': 'none'},
#  {'id': 4558,
#   'timestamp': 10000,
#   'x1': 227.091236,
#   'y1': 268.267119,
#   'x2': 240.816532,
#   'y2': 300.708723,
#   'trafficLightColor': 'none'},
#  {'id': 4559,
#   'timestamp': 10000,
#   'x1': 154.721502,
#   'y1': 278.56109,
#   'x2': 174.685566,
#   'y2': 314.745957,
#   'trafficLightColor': 'none'},
#  {'id': 4560,
#   'timestamp': 10000,
#   'x1': 139.748453,
#   'y1': 277.313336,
#   'x2': 150.978239,
#   'y2': 308.444806,
#   'trafficLightColor': 'none'},
#  {'id': 4561,
#   'timestamp': 10000,
#   'x1': 128.518666,
#   'y1': 274.755447,
#   'x2': 139.748454,
#   'y2': 304.701543,
#   'trafficLightColor': 'none'},
#  {'id': 4563,
#   'timestamp': 10000,
#   'x1': 1160.237248,
#   'y1': 200.690435,
#   'x2': 1259.033924,
#   'y2': 500.96902,
#   'trafficLightColor': 'none'},
#  {'id': 4675,
#   'timestamp': 10000,
#   'x1': 504.092633,
#   'y1': 300.708724,
#   'x2': 562.737075,
#   'y2': 486.624077,
#   'trafficLightColor': 'none'},
#  {'id': 4676,
#   'timestamp': 10000,
#   'x1': 591.435416,
#   'y1': 291.974447,
#   'x2': 661.309643,
#   'y2': 496.606108,
#   'trafficLightColor': 'none'},
#  {'id': 4677,
#   'timestamp': 10000,
#   'x1': 663.805151,
#   'y1': 301.956477,
#   'x2': 724.945099,
#   'y2': 494.110601,
#   'trafficLightColor': 'none'},
#  {'id': 4726,
#   'timestamp': 10000,
#   'x1': 308.391809,
#   'y1': 344.720687,
#   'x2': 324.537977,
#   'y2': 391.544575,
#   'trafficLightColor': 'none'},
#  {'id': 4734,
#   'timestamp': 10000,
#   'x1': 695.811398,
#   'y1': 354.009308,
#   'x2': 708.018616,
#   'y2': 396.734569,
#   'trafficLightColor': 'none'},
#  {'id': 4774,
#   'timestamp': 10000,
#   'x1': 749.867393,
#   'y1': 311.435065,
#   'x2': 798.33279,
#   'y2': 455.484995,
#   'trafficLightColor': 'none'},
#  {'id': 4775,
#   'timestamp': 10000,
#   'x1': 367.529262,
#   'y1': 350.476635,
#   'x2': 378.29935,
#   'y2': 382.7869,
#   'trafficLightColor': 'none'},
#  {'id': 4776,
#   'timestamp': 10000,
#   'x1': 382.338131,
#   'y1': 351.822896,
#   'x2': 390.415698,
#   'y2': 380.094378,
#   'trafficLightColor': 'none'},
#  {'id': 4789,
#   'timestamp': 10000,
#   'x1': 363.490478,
#   'y1': 282.26607,
#   'x2': 432.14979,
#   'y2': 553.313283,
#   'trafficLightColor': 'none'},
#  {'id': 4790,
#   'timestamp': 10000,
#   'x1': 1057.712443,
#   'y1': 358.5542,
#   'x2': 1147.911932,
#   'y2': 541.6457,
#   'trafficLightColor': 'none'},
#  {'id': 4847,
#   'timestamp': 10000,
#   'x1': 40.499986,
#   'y1': 333.835598,
#   'x2': 82.349971,
#   'y2': 437.785562,
#   'trafficLightColor': 'none'},
#  {'id': 4850,
#   'timestamp': 10000,
#   'x1': 512.99982,
#   'y1': 339.524882,
#   'x2': 527.849815,
#   'y2': 378.674867,
#   'trafficLightColor': 'none'},
#  {'id': 4891,
#   'timestamp': 10000,
#   'x1': 1188.735235,
#   'y1': 279.918493,
#   'x2': 1237.22505,
#   'y2': 352.653221,
#   'trafficLightColor': 'none'},
#  {'id': 4892,
#   'timestamp': 10000,
#   'x1': 1133.633168,
#   'y1': 279.918493,
#   'x2': 1185.429109,
#   'y2': 353.755261,
#   'trafficLightColor': 'none'},
#  {'id': 4893,
#   'timestamp': 10000,
#   'x1': 1067.510689,
#   'y1': 245.387863,
#   'x2': 1098.367846,
#   'y2': 346.775662,
#   'trafficLightColor': 'none'},
#  {'id': 4894,
#   'timestamp': 10000,
#   'x1': 1015.714747,
#   'y1': 253.469503,
#   'x2': 1049.87803,
#   'y2': 341.632805,
#   'trafficLightColor': 'none'},
#  {'id': 4895,
#   'timestamp': 10000,
#   'x1': 966.122888,
#   'y1': 256.775625,
#   'x2': 1000.28617,
#   'y2': 347.143011,
#   'trafficLightColor': 'none'},
#  {'id': 4896,
#   'timestamp': 10000,
#   'x1': 911.020823,
#   'y1': 268.163398,
#   'x2': 937.469813,
#   'y2': 332.081793,
#   'trafficLightColor': 'none'},
#  {'id': 4926,
#   'timestamp': 10000,
#   'x1': 17.468557,
#   'y1': 316.929527,
#   'x2': 54.901179,
#   'y2': 426.731884,
#   'trafficLightColor': 'none'},
#  {'id': 4927,
#   'timestamp': 10000,
#   'x1': 59.892194,
#   'y1': 330.654821,
#   'x2': 93.581553,
#   'y2': 421.740866,
#   'trafficLightColor': 'none'},
#  {'id': 4928,
#   'timestamp': 10000,
#   'x1': 1155.420244,
#   'y1': 291.974446,
#   'x2': 1270.213615,
#   'y2': 521.56119,
#   'trafficLightColor': 'none'},
#  {'id': 4929,
#   'timestamp': 10000,
#   'x1': 1084.298263,
#   'y1': 334.398083,
#   'x2': 1145.43821,
#   'y2': 430.475144,
#   'trafficLightColor': 'none'},
#  {'id': 4975,
#   'timestamp': 10000,
#   'x1': 719.042675,
#   'y1': 340.145936,
#   'x2': 748.105776,
#   'y2': 391.813673,
#   'trafficLightColor': 'none'},
#  {'id': 4976,
#   'timestamp': 10000,
#   'x1': 794.929664,
#   'y1': 330.996446,
#   'x2': 819.148916,
#   'y2': 384.278799,
#   'trafficLightColor': 'none'},
#  {'id': 5038,
#   'timestamp': 10000,
#   'x1': 977.878001,
#   'y1': 319.959339,
#   'x2': 1002.12291,
#   'y2': 355.22466,
#   'trafficLightColor': 'none'},
#  {'id': 5039,
#   'timestamp': 10000,
#   'x1': 920.939195,
#   'y1': 308.571567,
#   'x2': 971.633095,
#   'y2': 435.306319,
#   'trafficLightColor': 'none'},
#  {'id': 5040,
#   'timestamp': 10000,
#   'x1': 1043.26578,
#   'y1': 286.530741,
#   'x2': 1071.918854,
#   'y2': 333.918516,
#   'trafficLightColor': 'none'},
#  {'id': 5041,
#   'timestamp': 10000,
#   'x1': 115.346988,
#   'y1': 361.46955,
#   'x2': 130.775565,
#   'y2': 387.918541,
#   'trafficLightColor': 'none'},
#  {'id': 5042,
#   'timestamp': 10000,
#   'x1': 94.408203,
#   'y1': 359.265467,
#   'x2': 110.938824,
#   'y2': 375.796088,
#   'trafficLightColor': 'none'},
#  {'id': 5043,
#   'timestamp': 10000,
#   'x1': 0,
#   'y1': 360.367509,
#   'x2': 16.16327,
#   'y2': 379.102211,
#   'trafficLightColor': 'none'},
#  {'id': 5044,
#   'timestamp': 10000,
#   'x1': 203.510293,
#   'y1': 353.755261,
#   'x2': 222.244995,
#   'y2': 403.34712,
#   'trafficLightColor': 'none'},
#  {'id': 5045,
#   'timestamp': 10000,
#   'x1': 210.122541,
#   'y1': 354.122609,
#   'x2': 228.857243,
#   'y2': 404.816509,
#   'trafficLightColor': 'none'},
#  {'id': 5095,
#   'timestamp': 10000,
#   'x1': 765.551361,
#   'y1': 326.204228,
#   'x2': 784.286066,
#   'y2': 360.367508,
#   'trafficLightColor': 'none'},
#  {'id': 5096,
#   'timestamp': 10000,
#   'x1': 820.653433,
#   'y1': 352.653221,
#   'x2': 834.979972,
#   'y2': 389.020584,
#   'trafficLightColor': 'none'},
#  {'id': 5097,
#   'timestamp': 10000,
#   'x1': 842.694261,
#   'y1': 347.143013,
#   'x2': 857.020798,
#   'y2': 395.632833,
#   'trafficLightColor': 'none'},
#  {'id': 5098,
#   'timestamp': 10000,
#   'x1': 860.326922,
#   'y1': 352.653221,
#   'x2': 873.551416,
#   'y2': 384.612417,
#   'trafficLightColor': 'none'},
#  {'id': 5099,
#   'timestamp': 10000,
#   'x1': 881.265708,
#   'y1': 351.551178,
#   'x2': 897.796327,
#   'y2': 384.61242,
#   'trafficLightColor': 'none'},
#  {'id': 5100,
#   'timestamp': 10000,
#   'x1': 911.020823,
#   'y1': 347.143013,
#   'x2': 926.449402,
#   'y2': 391.224665,
#   'trafficLightColor': 'none'},
#  {'id': 5101,
#   'timestamp': 10000,
#   'x1': 949.592269,
#   'y1': 354.857302,
#   'x2': 966.122888,
#   'y2': 400.040996,
#   'trafficLightColor': 'none'},
#  {'id': 5102,
#   'timestamp': 10000,
#   'x1': 992.57188,
#   'y1': 348.245055,
#   'x2': 1019.020871,
#   'y2': 406.653245,
#   'trafficLightColor': 'none'},
#  {'id': 5103,
#   'timestamp': 10000,
#   'x1': 1015.714747,
#   'y1': 350.449137,
#   'x2': 1032.245367,
#   'y2': 390.122624,
#   'trafficLightColor': 'none'},
#  {'id': 5104,
#   'timestamp': 10000,
#   'x1': 1052.082111,
#   'y1': 349.347096,
#   'x2': 1077.429061,
#   'y2': 422.081822,
#   'trafficLightColor': 'none'},
#  {'id': 5105,
#   'timestamp': 10000,
#   'x1': 900.000411,
#   'y1': 346.040972,
#   'x2': 915.42899,
#   'y2': 406.940231,
#   'trafficLightColor': 'none'},
#  {'id': 5106,
#   'timestamp': 10000,
#   'x1': 970.531054,
#   'y1': 339.715711,
#   'x2': 995.14327,
#   'y2': 415.469576,
#   'trafficLightColor': 'none'},
#  {'id': 5308,
#   'timestamp': 10000,
#   'x1': 1242.598909,
#   'y1': 340.890769,
#   'x2': 1270.934575,
#   'y2': 409.867779,
#   'trafficLightColor': 'none'},
#  {'id': 5309,
#   'timestamp': 10000,
#   'x1': 926.972718,
#   'y1': 339.355225,
#   'x2': 954.61251,
#   'y2': 402.312529,
#   'trafficLightColor': 'none'},
#  {'id': 5310,
#   'timestamp': 10000,
#   'x1': 976.110128,
#   'y1': 337.819681,
#   'x2': 1000.678832,
#   'y2': 377.743825,
#   'trafficLightColor': 'none'},
#  {'id': 5311,
#   'timestamp': 10000,
#   'x1': 354.214806,
#   'y1': 320.50562,
#   'x2': 372.641335,
#   'y2': 378.915523,
#   'trafficLightColor': 'none'},
#  {'id': 5489,
#   'timestamp': 10000,
#   'x1': 1050.014309,
#   'y1': 268.224257,
#   'x2': 1121.690625,
#   'y2': 392.346658,
#   'trafficLightColor': 'none'},
#  {'id': 5507,
#   'timestamp': 10000,
#   'x1': 233.072203,
#   'y1': 260.536125,
#   'x2': 264.247466,
#   'y2': 357.030986,
#   'trafficLightColor': 'none'},
#  {'id': 5508,
#   'timestamp': 10000,
#   'x1': 256.824785,
#   'y1': 262.020662,
#   'x2': 288.000048,
#   'y2': 358.515523,
#   'trafficLightColor': 'none'},
#  {'id': 5522,
#   'timestamp': 10000,
#   'x1': 0,
#   'y1': 263.505198,
#   'x2': 23.752581,
#   'y2': 337.732014,
#   'trafficLightColor': 'none'},
#  {'id': 5523,
#   'timestamp': 10000,
#   'x1': 903.430544,
#   'y1': 293.722001,
#   'x2': 925.966838,
#   'y2': 319.197811,
#   'trafficLightColor': 'none'},
#  {'id': 5586,
#   'timestamp': 10000,
#   'x1': 157.357143,
#   'y1': 227.86394,
#   'x2': 241.926619,
#   'y2': 454.114744,
#   'trafficLightColor': 'none'},
#  {'id': 5956,
#   'timestamp': 10000,
#   'x1': 1118.723468,
#   'y1': 241.347046,
#   'x2': 1161.703079,
#   'y2': 343.836889,
#   'trafficLightColor': 'none'},
#  {'id': 6003,
#   'timestamp': 10000,
#   'x1': 796.329025,
#   'y1': 311.621043,
#   'x2': 823.777512,
#   'y2': 379.434948,
#   'trafficLightColor': 'none'},
#  {'id': 6004,
#   'timestamp': 10000,
#   'x1': 875.445249,
#   'y1': 319.694128,
#   'x2': 899.664501,
#   'y2': 371.361867,
#   'trafficLightColor': 'none'},
#  {'id': 6041,
#   'timestamp': 10000,
#   'x1': 251.999831,
#   'y1': 309.937287,
#   'x2': 268.874819,
#   'y2': 338.624769,
#   'trafficLightColor': 'none'},
#  {'id': 6043,
#   'timestamp': 10000,
#   'x1': 694.687032,
#   'y1': 321.187285,
#   'x2': 708.187022,
#   'y2': 358.312259,
#   'trafficLightColor': 'none'},
#  {'id': 6048,
#   'timestamp': 10000,
#   'x1': 390.149863,
#   'y1': 314.099887,
#   'x2': 410.399856,
#   'y2': 350.549874,
#   'trafficLightColor': 'none'},
#  {'id': 6049,
#   'timestamp': 10000,
#   'x1': 418.499854,
#   'y1': 320.849884,
#   'x2': 434.699848,
#   'y2': 354.599872,
#   'trafficLightColor': 'none'},
#  {'id': 6050,
#   'timestamp': 10000,
#   'x1': 708.749752,
#   'y1': 324.899883,
#   'x2': 724.949746,
#   'y2': 357.299872,
#   'trafficLightColor': 'none'},
#  {'id': 6357,
#   'timestamp': 10000,
#   'x1': 497.607441,
#   'y1': 424.595062,
#   'x2': 515.579718,
#   'y2': 456.046548,
#   'trafficLightColor': 'none'},
#  {'id': 6590,
#   'timestamp': 10000,
#   'x1': 1163.404411,
#   'y1': 283.877488,
#   'x2': 1200.746777,
#   'y2': 316.826635,
#   'trafficLightColor': 'none'},
#  {'id': 6591,
#   'timestamp': 10000,
#   'x1': 808.651936,
#   'y1': 283.877488,
#   'x2': 828.421422,
#   'y2': 310.236806,
#   'trafficLightColor': 'none'},
#  {'id': 6691,
#   'timestamp': 10000,
#   'x1': 933.079722,
#   'y1': 341.29761,
#   'x2': 965.014001,
#   'y2': 458.057317,
#   'trafficLightColor': 'none'},
#  {'id': 6692,
#   'timestamp': 10000,
#   'x1': 1143.646377,
#   'y1': 336.307878,
#   'x2': 1195.539581,
#   'y2': 502.964897,
#   'trafficLightColor': 'none'},
#  {'id': 6806,
#   'timestamp': 10000,
#   'x1': 530.802365,
#   'y1': 410.502088,
#   'x2': 550.764437,
#   'y2': 463.387183,
#   'trafficLightColor': 'none'},
#  {'id': 6807,
#   'timestamp': 10000,
#   'x1': 593.75967,
#   'y1': 382.862297,
#   'x2': 642.897078,
#   'y2': 537.952242,
#   'trafficLightColor': 'none'},
#  {'id': 6827,
#   'timestamp': 10000,
#   'x1': 398.745579,
#   'y1': 421.250899,
#   'x2': 423.314283,
#   'y2': 473.459395,
#   'trafficLightColor': 'none'},
#  {'id': 6829,
#   'timestamp': 10000,
#   'x1': 1248.981168,
#   'y1': 308.13729,
#   'x2': 1279.356148,
#   'y2': 638.887062,
#   'trafficLightColor': 'none'},
#  {'id': 6901,
#   'timestamp': 10000,
#   'x1': 799.228564,
#   'y1': 352.752305,
#   'x2': 818.539821,
#   'y2': 413.260912,
#   'trafficLightColor': 'none'},
#  {'id': 6938,
#   'timestamp': 10000,
#   'x1': 718.477302,
#   'y1': 383.723853,
#   'x2': 740.012044,
#   'y2': 435.603004,
#   'trafficLightColor': 'none'},
#  {'id': 7070,
#   'timestamp': 10000,
#   'x1': 1063.356295,
#   'y1': 266.962312,
#   'x2': 1081.918782,
#   'y2': 304.087287,
#   'trafficLightColor': 'none'},
#  {'id': 7071,
#   'timestamp': 10000,
#   'x1': 990.793845,
#   'y1': 275.399807,
#   'x2': 1012.73133,
#   'y2': 310.837282,
#   'trafficLightColor': 'none'},
#  {'id': 7072,
#   'timestamp': 10000,
#   'x1': 970.543859,
#   'y1': 265.274813,
#   'x2': 992.481344,
#   'y2': 314.212279,
#   'trafficLightColor': 'none'},
#  {'id': 7073,
#   'timestamp': 10000,
#   'x1': 862.543933,
#   'y1': 266.962312,
#   'x2': 881.106421,
#   'y2': 305.774785,
#   'trafficLightColor': 'none'},
#  {'id': 7074,
#   'timestamp': 10000,
#   'x1': 820.356462,
#   'y1': 266.962312,
#   'x2': 833.856453,
#   'y2': 302.399788,
#   'trafficLightColor': 'none'},
#  {'id': 7116,
#   'timestamp': 10000,
#   'x1': 1059.991856,
#   'y1': 311.040081,
#   'x2': 1093.756075,
#   'y2': 350.943251,
#   'trafficLightColor': 'none'},
#  {'id': 7118,
#   'timestamp': 10000,
#   'x1': 259.882174,
#   'y1': 324.341136,
#   'x2': 275.229547,
#   'y2': 346.850616,
#   'trafficLightColor': 'none'},
#  {'id': 7119,
#   'timestamp': 10000,
#   'x1': 229.187429,
#   'y1': 314.109556,
#   'x2': 246.581117,
#   'y2': 345.827458,
#   'trafficLightColor': 'none'},
#  {'id': 7120,
#   'timestamp': 10000,
#   'x1': 202.585316,
#   'y1': 312.063239,
#   'x2': 221.002163,
#   'y2': 338.665354,
#   'trafficLightColor': 'none'},
#  {'id': 7168,
#   'timestamp': 10000,
#   'x1': 1092.486739,
#   'y1': 273.374812,
#   'x2': 1111.049226,
#   'y2': 295.312297,
#   'trafficLightColor': 'none'},
#  {'id': 7169,
#   'timestamp': 10000,
#   'x1': 1122.861718,
#   'y1': 273.374812,
#   'x2': 1141.424206,
# ...
#   'y2': 396.435021,
#   'trafficLightColor': 'none'},
#  {'id': 20373,
#   'timestamp': 10000,
#   'x1': 962.994492,
#   'y1': 342.598168,
#   'x2': 983.550382,
#   'y2': 397.413874,
#   'trafficLightColor': 'none'},
#  {'id': 20374,
#   'timestamp': 10000,
#   'x1': 1040.323792,
#   'y1': 338.682759,
#   'x2': 1075.562461,
#   'y2': 429.715986,
#   'trafficLightColor': 'none'},
#  {'id': 20375,
#   'timestamp': 10000,
#   'x1': 1060.879682,
#   'y1': 323.021129,
#   'x2': 1088.287536,
#   'y2': 397.413872,
#   'trafficLightColor': 'none'},
#  {'id': 20376,
#   'timestamp': 10000,
#   'x1': 1082.414425,
#   'y1': 321.063425,
#   'x2': 1114.716537,
#   'y2': 417.969764,
#   'trafficLightColor': 'none'},
#  {'id': 20377,
#   'timestamp': 10000,
#   'x1': 1085.350979,
#   'y1': 320.084572,
#   'x2': 1118.631944,
#   'y2': 413.075504,
#   'trafficLightColor': 'none'},
#  {'id': 20378,
#   'timestamp': 10000,
#   'x1': 1116.674241,
#   'y1': 321.063425,
#   'x2': 1154.849464,
#   'y2': 407.202393,
#   'trafficLightColor': 'none'},
#  {'id': 20379,
#   'timestamp': 10000,
#   'x1': 1106.885722,
#   'y1': 325.957684,
#   'x2': 1138.208983,
#   'y2': 418.948615,
#   'trafficLightColor': 'none'},
#  {'id': 20380,
#   'timestamp': 10000,
#   'x1': 1147.018649,
#   'y1': 321.063425,
#   'x2': 1182.257318,
#   'y2': 411.1178,
#   'trafficLightColor': 'none'},
#  {'id': 20381,
#   'timestamp': 10000,
#   'x1': 1218.083333,
#   'y1': 336.725055,
#   'x2': 1247.448891,
#   'y2': 395.456169,
#   'trafficLightColor': 'none'},
#  {'id': 20382,
#   'timestamp': 10000,
#   'x1': 1180.886963,
#   'y1': 334.767351,
#   'x2': 1231.787261,
#   'y2': 432.652543,
#   'trafficLightColor': 'none'},
#  {'id': 20383,
#   'timestamp': 10000,
#   'x1': 1258.216262,
#   'y1': 327.915387,
#   'x2': 1279.751005,
#   'y2': 431.67369,
#   'trafficLightColor': 'none'},
#  {'id': 20413,
#   'timestamp': 10000,
#   'x1': 679.408468,
#   'y1': 351.551178,
#   'x2': 730.102369,
#   'y2': 494.816549,
#   'trafficLightColor': 'none'},
#  {'id': 20414,
#   'timestamp': 10000,
#   'x1': 1244.501675,
#   'y1': 336.144125,
#   'x2': 1269.848625,
#   'y2': 359.286992,
#   'trafficLightColor': 'none'},
#  {'id': 20502,
#   'timestamp': 10000,
#   'x1': 664.283655,
#   'y1': 373.106633,
#   'x2': 730.250445,
#   'y2': 577.73831,
#   'trafficLightColor': 'none'},
#  {'id': 20524,
#   'timestamp': 10000,
#   'x1': 1160.22597,
#   'y1': 500.228398,
#   'x2': 1188.682075,
#   'y2': 543.661403,
#   'trafficLightColor': 'none'},
#  {'id': 20568,
#   'timestamp': 10000,
#   'x1': 914.856397,
#   'y1': 516.712139,
#   'x2': 924.98139,
#   'y2': 538.649624,
#   'trafficLightColor': 'none'},
#  {'id': 20569,
#   'timestamp': 10000,
#   'x1': 908.106402,
#   'y1': 515.024641,
#   'x2': 918.231395,
#   'y2': 540.337123,
#   'trafficLightColor': 'none'},
#  {'id': 20570,
#   'timestamp': 10000,
#   'x1': 182.481901,
#   'y1': 503.212149,
#   'x2': 212.85688,
#   'y2': 590.962089,
#   'trafficLightColor': 'none'},
#  {'id': 20571,
#   'timestamp': 10000,
#   'x1': 138.606931,
#   'y1': 499.837151,
#   'x2': 172.356909,
#   'y2': 590.962088,
#   'trafficLightColor': 'none'},
#  {'id': 20572,
#   'timestamp': 10000,
#   'x1': 118.356945,
#   'y1': 498.149652,
#   'x2': 148.731924,
#   'y2': 592.649587,
#   'trafficLightColor': 'none'},
#  {'id': 20573,
#   'timestamp': 10000,
#   'x1': 452.481715,
#   'y1': 504.899648,
#   'x2': 484.544193,
#   'y2': 565.649606,
#   'trafficLightColor': 'none'},
#  {'id': 20574,
#   'timestamp': 10000,
#   'x1': 433.919228,
#   'y1': 509.962144,
#   'x2': 452.481715,
#   'y2': 572.399602,
#   'trafficLightColor': 'none'},
#  {'id': 20575,
#   'timestamp': 10000,
#   'x1': 403.544249,
#   'y1': 516.712139,
#   'x2': 418.731738,
#   'y2': 565.649606,
#   'trafficLightColor': 'none'},
#  {'id': 20576,
#   'timestamp': 10000,
#   'x1': 525.044166,
#   'y1': 508.274644,
#   'x2': 540.231656,
#   'y2': 526.837132,
#   'trafficLightColor': 'none'},
#  {'id': 20577,
#   'timestamp': 10000,
#   'x1': 503.10668,
#   'y1': 509.962144,
#   'x2': 521.669168,
#   'y2': 528.524632,
#   'trafficLightColor': 'none'},
#  {'id': 20578,
#   'timestamp': 10000,
#   'x1': 1178.106216,
#   'y1': 518.399639,
#   'x2': 1194.981205,
#   'y2': 557.212112,
#   'trafficLightColor': 'none'},
#  {'id': 20581,
#   'timestamp': 10000,
#   'x1': 152.106923,
#   'y1': 509.962144,
#   'x2': 199.35689,
#   'y2': 606.149578,
#   'trafficLightColor': 'none'},
#  {'id': 20586,
#   'timestamp': 10000,
#   'x1': 415.356742,
#   'y1': 508.274644,
#   'x2': 442.356723,
#   'y2': 572.399601,
#   'trafficLightColor': 'none'},
#  {'id': 20587,
#   'timestamp': 10000,
#   'x1': 813.606467,
#   'y1': 516.712139,
#   'x2': 827.106458,
#   'y2': 536.962126,
#   'trafficLightColor': 'none'},
#  {'id': 20642,
#   'timestamp': 10000,
#   'x1': 795.363143,
#   'y1': 278.426997,
#   'x2': 822.307692,
#   'y2': 358.262696,
#   'trafficLightColor': 'none'},
#  {'id': 20721,
#   'timestamp': 10000,
#   'x1': 156.61783,
#   'y1': 326.690805,
#   'x2': 179.222466,
#   'y2': 388.046242,
#   'trafficLightColor': 'none'},
#  {'id': 20763,
#   'timestamp': 10000,
#   'x1': 0.866811,
#   'y1': 251.521174,
#   'x2': 47.880115,
#   'y2': 492.464355,
#   'trafficLightColor': 'none'},
#  {'id': 20764,
#   'timestamp': 10000,
#   'x1': 57.752902,
#   'y1': 293.833147,
#   'x2': 93.806992,
#   'y2': 441.092452,
#   'trafficLightColor': 'none'},
#  {'id': 20765,
#   'timestamp': 10000,
#   'x1': 958.483727,
#   'y1': 353.187443,
#   'x2': 966.711055,
#   'y2': 369.642099,
#   'trafficLightColor': 'none'},
#  {'id': 20766,
#   'timestamp': 10000,
#   'x1': 950.256399,
#   'y1': 349.661445,
#   'x2': 959.65906,
#   'y2': 373.168097,
#   'trafficLightColor': 'none'},
#  {'id': 20767,
#   'timestamp': 10000,
#   'x1': 939.678405,
#   'y1': 353.187443,
#   'x2': 951.431731,
#   'y2': 373.168097,
#   'trafficLightColor': 'none'},
#  {'id': 20768,
#   'timestamp': 10000,
#   'x1': 919.697751,
#   'y1': 355.538108,
#   'x2': 931.451077,
#   'y2': 380.220093,
#   'trafficLightColor': 'none'},
#  {'id': 20769,
#   'timestamp': 10000,
#   'x1': 893.840434,
#   'y1': 357.888774,
#   'x2': 906.769093,
#   'y2': 387.272088,
#   'trafficLightColor': 'none'},
#  {'id': 20770,
#   'timestamp': 10000,
#   'x1': 880.911776,
#   'y1': 352.012111,
#   'x2': 893.840434,
#   'y2': 384.921423,
#   'trafficLightColor': 'none'},
#  {'id': 20771,
#   'timestamp': 10000,
#   'x1': 905.59376,
#   'y1': 347.31078,
#   'x2': 920.873084,
#   'y2': 387.272088,
#   'trafficLightColor': 'none'},
#  {'id': 20784,
#   'timestamp': 10000,
#   'x1': 145.43272,
#   'y1': 305.92229,
#   'x2': 183.043363,
#   'y2': 369.054433,
#   'trafficLightColor': 'none'},
#  {'id': 20804,
#   'timestamp': 10000,
#   'x1': 326.575012,
#   'y1': 335.260433,
#   'x2': 340.39491,
#   'y2': 356.758049,
#   'trafficLightColor': 'none'},
#  {'id': 20867,
#   'timestamp': 10000,
#   'x1': 1152.278574,
#   'y1': 298.391473,
#   'x2': 1182.224671,
#   'y2': 400.707304,
#   'trafficLightColor': 'none'},
#  {'id': 20868,
#   'timestamp': 10000,
#   'x1': 1108.607183,
#   'y1': 285.913929,
#   'x2': 1132.314508,
#   'y2': 320.851047,
#   'trafficLightColor': 'none'},
#  {'id': 20869,
#   'timestamp': 10000,
#   'x1': 1047.467233,
#   'y1': 280.922914,
#   'x2': 1064.935789,
#   'y2': 334.576341,
#   'trafficLightColor': 'none'},
#  {'id': 20870,
#   'timestamp': 10000,
#   'x1': 1048.714988,
#   'y1': 289.657193,
#   'x2': 1086.147608,
#   'y2': 343.310617,
#   'trafficLightColor': 'none'},
#  {'id': 20871,
#   'timestamp': 10000,
#   'x1': 975.0975,
#   'y1': 300.886977,
#   'x2': 1001.300335,
#   'y2': 350.79714,
#   'trafficLightColor': 'none'},
#  {'id': 20873,
#   'timestamp': 10000,
#   'x1': 1121.084722,
#   'y1': 293.756945,
#   'x2': 1156.021835,
#   'y2': 426.018873,
#   'trafficLightColor': 'none'},
#  {'id': 20915,
#   'timestamp': 10000,
#   'x1': 795.706186,
#   'y1': 307.367438,
#   'x2': 811.673323,
#   'y2': 356.266803,
#   'trafficLightColor': 'none'},
#  {'id': 20965,
#   'timestamp': 10000,
#   'x1': 157.716111,
#   'y1': 361.848672,
#   'x2': 173.936914,
#   'y2': 391.794769,
#   'trafficLightColor': 'none'},
#  {'id': 21132,
#   'timestamp': 10000,
#   'x1': 87.342783,
#   'y1': 384.308245,
#   'x2': 117.288881,
#   'y2': 440.457177,
#   'trafficLightColor': 'none'},
#  {'id': 21133,
#   'timestamp': 10000,
#   'x1': 112.297864,
#   'y1': 386.803753,
#   'x2': 133.509684,
#   'y2': 417.997604,
#   'trafficLightColor': 'none'},
#  {'id': 21134,
#   'timestamp': 10000,
#   'x1': 142.243961,
#   'y1': 378.069475,
#   'x2': 162.208026,
#   'y2': 401.776802,
#   'trafficLightColor': 'none'},
#  {'id': 21135,
#   'timestamp': 10000,
#   'x1': 6.23877,
#   'y1': 388.051507,
#   'x2': 27.450589,
#   'y2': 447.943701,
#   'trafficLightColor': 'none'},
#  {'id': 21136,
#   'timestamp': 10000,
#   'x1': 0,
#   'y1': 393.042523,
#   'x2': 18.716311,
#   'y2': 446.695947,
#   'trafficLightColor': 'none'},
#  {'id': 21170,
#   'timestamp': 10000,
#   'x1': 1266.561946,
#   'y1': 414.860078,
#   'x2': 1278.543464,
#   'y2': 456.795393,
#   'trafficLightColor': 'none'},
#  {'id': 21171,
#   'timestamp': 10000,
#   'x1': 829.236521,
#   'y1': 371.427074,
#   'x2': 841.218039,
#   'y2': 395.390111,
#   'trafficLightColor': 'none'},
#  {'id': 21172,
#   'timestamp': 10000,
#   'x1': 830.73421,
#   'y1': 371.427074,
#   'x2': 844.213419,
#   'y2': 419.35315,
#   'trafficLightColor': 'none'},
#  {'id': 21173,
#   'timestamp': 10000,
#   'x1': 817.255002,
#   'y1': 368.431693,
#   'x2': 827.738829,
#   'y2': 416.357769,
#   'trafficLightColor': 'none'},
#  {'id': 21179,
#   'timestamp': 10000,
#   'x1': 1145.24907,
#   'y1': 383.408592,
#   'x2': 1164.719038,
#   'y2': 402.878559,
#   'trafficLightColor': 'none'},
#  {'id': 21180,
#   'timestamp': 10000,
#   'x1': 1164.719038,
#   'y1': 386.403973,
#   'x2': 1178.198246,
#   'y2': 401.380871,
#   'trafficLightColor': 'none'},
#  {'id': 21192,
#   'timestamp': 10000,
#   'x1': 369.649546,
#   'y1': 368.165009,
#   'x2': 396.371198,
#   'y2': 440.90729,
#   'trafficLightColor': 'none'},
#  {'id': 21261,
#   'timestamp': 10000,
#   'x1': 1164.605147,
#   'y1': 304.821318,
#   'x2': 1187.864603,
#   'y2': 335.425868,
#   'trafficLightColor': 'none'},
#  {'id': 21351,
#   'timestamp': 10000,
#   'x1': 948.293072,
#   'y1': 364.34418,
#   'x2': 1000.698742,
#   'y2': 466.660012,
#   'trafficLightColor': 'none'},
#  {'id': 21352,
#   'timestamp': 10000,
#   'x1': 902.126173,
#   'y1': 360.600918,
#   'x2': 953.284089,
#   'y2': 475.394291,
#   'trafficLightColor': 'none'},
#  {'id': 21353,
#   'timestamp': 10000,
#   'x1': 870.932322,
#   'y1': 360.600918,
#   'x2': 910.860451,
#   'y2': 471.651028,
#   'trafficLightColor': 'none'},
#  {'id': 21377,
#   'timestamp': 10000,
#   'x1': 392.394389,
#   'y1': 354.169001,
#   'x2': 434.12997,
#   'y2': 437.640169,
#   'trafficLightColor': 'none'},
#  {'id': 21378,
#   'timestamp': 10000,
#   'x1': 352.855411,
#   'y1': 360.75883,
#   'x2': 377.018118,
#   'y2': 434.345258,
#   'trafficLightColor': 'none'},
#  {'id': 21379,
#   'timestamp': 10000,
#   'x1': 316.611352,
#   'y1': 364.053745,
#   'x2': 336.380838,
#   'y2': 442.033391,
#   'trafficLightColor': 'none'},
#  {'id': 21380,
#   'timestamp': 10000,
#   'x1': 301.235083,
#   'y1': 356.365609,
#   'x2': 321.00457,
#   'y2': 438.738477,
#   'trafficLightColor': 'none'},
#  {'id': 21381,
#   'timestamp': 10000,
#   'x1': 282.5639,
#   'y1': 356.365609,
#   'x2': 306.726607,
#   'y2': 446.42661,
#   'trafficLightColor': 'none'},
#  {'id': 21382,
#   'timestamp': 10000,
#   'x1': 259.499498,
#   'y1': 357.463915,
#   'x2': 281.465597,
#   'y2': 399.1995,
#   'trafficLightColor': 'none'},
#  {'id': 21383,
#   'timestamp': 10000,
#   'x1': 228.74696,
#   'y1': 354.169001,
#   'x2': 259.499497,
#   'y2': 399.1995,
#   'trafficLightColor': 'none'},
#  {'id': 21384,
#   'timestamp': 10000,
#   'x1': 485.725333,
#   'y1': 369.57959,
#   'x2': 503.29821,
#   'y2': 423.396531,
#   'trafficLightColor': 'none'},
#  {'id': 21385,
#   'timestamp': 10000,
#   'x1': 498.90499,
#   'y1': 367.38298,
#   'x2': 514.281256,
#   'y2': 425.593138,
#   'trafficLightColor': 'none'},
#  {'id': 21386,
#   'timestamp': 10000,
#   'x1': 453.87449,
#   'y1': 372.874505,
#   'x2': 465.95584,
#   'y2': 400.332128,
#   'trafficLightColor': 'none'},
#  {'id': 21387,
#   'timestamp': 10000,
#   'x1': 901.433726,
#   'y1': 338.827054,
#   'x2': 926.694738,
#   'y2': 424.494834,
#   'trafficLightColor': 'none'},
#  {'id': 21388,
#   'timestamp': 10000,
#   'x1': 920.10491,
#   'y1': 339.925359,
#   'x2': 944.267617,
#   'y2': 421.199919,
#   'trafficLightColor': 'none'},
#  {'id': 21389,
#   'timestamp': 10000,
#   'x1': 936.579484,
#   'y1': 325.647396,
#   'x2': 986.003204,
#   'y2': 428.888056,
#   'trafficLightColor': 'none'},
#  {'id': 21390,
#   'timestamp': 10000,
#   'x1': 1136.470971,
#   'y1': 338.827054,
#   'x2': 1169.420118,
#   'y2': 414.573817,
#   'trafficLightColor': 'none'},
#  {'id': 21391,
#   'timestamp': 10000,
#   'x1': 1106.816739,
#   'y1': 339.925359,
#   'x2': 1121.0947,
#   'y2': 403.627044,
#   'trafficLightColor': 'none'},
#  {'id': 21392,
#   'timestamp': 10000,
#   'x1': 987.101509,
#   'y1': 341.023663,
#   'x2': 1004.674387,
#   'y2': 400.332128,
#   'trafficLightColor': 'none'},
#  {'id': 21404,
#   'timestamp': 10000,
#   'x1': 883.859405,
#   'y1': 340.322596,
#   'x2': 904.670499,
#   'y2': 427.239521,
#   'trafficLightColor': 'none'},
#  {'id': 21451,
#   'timestamp': 10000,
#   'x1': 1193.458012,
#   'y1': 293.698078,
#   'x2': 1242.40769,
#   'y2': 365.374395,
#   'trafficLightColor': 'none'},
#  {'id': 21452,
#   'timestamp': 10000,
#   'x1': 1037.867958,
#   'y1': 276.21605,
#   'x2': 1058.846392,
#   'y2': 307.683701,
#   'trafficLightColor': 'none'},
#  {'id': 21547,
#   'timestamp': 10000,
#   'x1': 288.73479,
#   'y1': 282.33476,
#   'x2': 304.163368,
#   'y2': 331.243768,
#   'trafficLightColor': 'none'},
#  {'id': 21548,
#   'timestamp': 10000,
#   'x1': 264.328279,
#   'y1': 297.194484,
#   'x2': 295.795932,
#   'y2': 368.870801,
#   'trafficLightColor': 'none'},
#  {'id': 21550,
#   'timestamp': 10000,
#   'x1': 300.857244,
#   'y1': 301.488653,
#   'x2': 325.102153,
#   'y2': 356.590719,
#   'trafficLightColor': 'none'},
#  {'id': 21598,
#   'timestamp': 10000,
#   'x1': 832.16043,
#   'y1': 315.213499,
#   'x2': 849.733308,
#   'y2': 333.884679,
#   'trafficLightColor': 'none'},
#  {'id': 21887,
#   'timestamp': 10000,
#   'x1': 711.684197,
#   'y1': 467.332433,
#   'x2': 718.121281,
#   'y2': 478.919188,
#   'trafficLightColor': 'none'},
#  {'id': 21888,
#   'timestamp': 10000,
#   'x1': 697.522606,
#   'y1': 464.757599,
#   'x2': 709.109362,
#   'y2': 482.781439,
#   'trafficLightColor': 'none'},
#  {'id': 21890,
#   'timestamp': 10000,
#   'x1': 612.553075,
#   'y1': 462.182764,
#   'x2': 626.714664,
#   'y2': 507.242366,
#   'trafficLightColor': 'none'},
#  {'id': 21891,
#   'timestamp': 10000,
#   'x1': 598.391485,
#   'y1': 468.61985,
#   'x2': 613.840491,
#   'y2': 511.104616,
#   'trafficLightColor': 'none'},
#  {'id': 21925,
#   'timestamp': 10000,
#   'x1': 1115.492113,
#   'y1': 455.430226,
#   'x2': 1244.01078,
#   'y2': 701.237772,
#   'trafficLightColor': 'none'},
#  {'id': 21972,
#   'timestamp': 10000,
#   'x1': 712.114761,
#   'y1': 383.709948,
#   'x2': 723.860984,
#   'y2': 402.308132,
#   'trafficLightColor': 'none'},
#  {'id': 21973,
#   'timestamp': 10000,
#   'x1': 703.305092,
#   'y1': 381.752242,
#   'x2': 717.00902,
#   'y2': 415.033207,
#   'trafficLightColor': 'none'},
#  {'id': 21974,
#   'timestamp': 10000,
#   'x1': 697.431983,
#   'y1': 380.773391,
#   'x2': 714.072465,
#   'y2': 412.096653,
#   'trafficLightColor': 'none'},
#  {'id': 21975,
#   'timestamp': 10000,
#   'x1': 689.601168,
#   'y1': 380.773391,
#   'x2': 698.410835,
#   'y2': 394.477319,
#   'trafficLightColor': 'none'},
#  {'id': 22064,
#   'timestamp': 10000,
#   'x1': 2.516273,
#   'y1': 329.991242,
#   'x2': 22.646459,
#   'y2': 376.003093,
#   'trafficLightColor': 'none'},
#  {'id': 22065,
#   'timestamp': 10000,
#   'x1': 149.179048,
#   'y1': 329.991242,
#   'x2': 160.682011,
#   'y2': 360.186521,
#   'trafficLightColor': 'none'},
#  {'id': 22066,
#   'timestamp': 10000,
#   'x1': 169.309233,
#   'y1': 328.553373,
#   'x2': 180.812196,
#   'y2': 363.062261,
#   'trafficLightColor': 'none'},
#  {'id': 22067,
#   'timestamp': 10000,
#   'x1': 157.806271,
#   'y1': 328.553373,
#   'x2': 170.747104,
#   'y2': 363.062261,
#   'trafficLightColor': 'none'},
#  {'id': 22068,
#   'timestamp': 10000,
#   'x1': 797.658572,
#   'y1': 335.742725,
#   'x2': 814.913015,
#   'y2': 383.192447,
#   'trafficLightColor': 'none'},
#  {'id': 22069,
#   'timestamp': 10000,
#   'x1': 819.226627,
#   'y1': 334.304854,
#   'x2': 835.043201,
#   'y2': 381.754576,
#   'trafficLightColor': 'none'},
#  {'id': 22070,
#   'timestamp': 10000,
#   'x1': 850.859775,
#   'y1': 331.429114,
#   'x2': 868.114218,
#   'y2': 357.310779,
#   'trafficLightColor': 'none'},
#  {'id': 22071,
#   'timestamp': 10000,
#   'x1': 662.49876,
#   'y1': 341.494205,
#   'x2': 676.877463,
#   'y2': 374.565224,
#   'trafficLightColor': 'none'},
#  {'id': 22072,
#   'timestamp': 10000,
#   'x1': 635.179224,
#   'y1': 340.056336,
#   'x2': 652.433667,
#   'y2': 371.689484,
#   'trafficLightColor': 'none'},
#  ...]

# %%
import pandas as pd

output = pd.DataFrame(output_data)

# %%
output
# Out:
#             id  timestamp trafficLightColor           x1           x2  \
# 0           14      10000              none   423.158909   434.176547
# 1           15      10000              none   563.939839   573.733294
# 2           16      10000              none   656.977672   666.771127
# 3           60      10000              none   695.316564   712.961393
# 4          133      10000              none   912.122852   949.046862
# 5          206      10000              none   199.056526   316.518755
# 6          207      10000              none   727.531679   745.151014
# 7          208      10000              none   862.613240   877.296017
# 8          209      10000              none   884.637407   896.383632
# 9          210      10000              none   872.891186   890.510521
# 10         211      10000              none   852.335296   868.486352
# 11         212      10000              none   790.667626   817.096628
# 12         213      10000              none   731.936512   792.135904
# 13         214      10000              none   883.169131   903.725022
# 14         292      10000              none  1097.322996  1127.276793
# 15         355      10000              none   629.261939   643.944715
# 16         357      10000              none   676.246831   696.802719
# 17         358      10000              none   712.953778   737.914501
# 18         359      10000              none   739.382779   768.748336
# 19         360      10000              none   981.648624  1016.887292
# 20         361      10000              none  1037.443182  1065.340458
# 21         362      10000              none   790.772505   815.733228
# 22         363      10000              none   815.733228   834.820839
# 23         364      10000              none   836.289118   867.122951
# 24         365      10000              none   865.654672   902.361619
# 25         366      10000              none   902.361619   933.195457
# 26         367      10000              none   937.600289   978.712069
# 27         368      10000              none  1178.376714  1247.805236
# 28         369      10000              none  1120.250509  1152.542848
# 29         382      10000              none  1240.223695  1278.612295
# ...        ...        ...               ...          ...          ...
# 91319  1940635      10000              none   533.167605   539.779853
# 91320  1940663      10000              none   532.235813   545.596639
# 91321  1940664      10000              none   505.514158   515.905912
# 91322  1940700      10000              none   692.222951   702.993040
# 91323  1940706      10000              none   503.052868   515.169216
# 91324  1940729      10000              none  1206.052389  1276.860334
# 91325  1940730      10000              none   658.900092   729.708037
# 91326  1940731      10000              none  1020.664317  1042.550409
# 91327  1940753      10000              none  1037.400741  1038.688158
# 91328  1940754      10000              none   449.051093   464.500100
# 91329  1940789      10000              none   677.530445   686.264724
# 91330  1940790      10000              none   697.494508   712.467554
# 91331  1940791      10000              none   334.398084   349.371134
# 91332  1940855      10000              none   721.066543   743.397862
# 91333  1940989      10000              none   841.036009   862.522330
# 91334  1941028      10000              none   153.473747   184.667598
# 91335  1941029      10000              none  1116.739868  1154.172490
# 91336  1941030      10000              none  1045.617888  1089.289278
# 91337  1941102      10000              none   588.998245   608.834973
# 91338  1941151      10000              none   342.487331   366.450369
# 91339  1941152      10000              none   324.515054   346.980401
# 91340  1941153      10000              none   216.681387   243.639804
# 91341  1941154      10000              none   806.771172   836.724969
# 91342  1941155      10000              none  1049.396921  1101.816065
# 91343  1941156      10000              none  1139.258311  1206.654352
# 91344  1941177      10000              none     4.991016    42.423636
# 91345  1941185      10000              none   421.740866   431.722899
# 91346  1941187      10000              none   950.788582   973.248153
# 91347  1941188      10000              none   939.558793   954.531842
# 91348  1941189      10000              none   910.860451   925.833500
#
#                y1          y2
# 0      336.241987  358.277263
# 1      324.000165  348.483804
# 2      315.838956  345.219323
# 3      343.179158  386.140482
# 4      350.279126  436.102500
# 5      335.816133  604.510982
# 6      390.561910  444.888191
# 7      384.688798  433.141967
# 8      383.220520  419.927465
# 9      384.688798  434.610245
# 10     389.093632  434.610248
# 11     381.752242  453.697858
# 12     397.903299  543.262806
# 13     384.688798  455.166134
# 14     307.026412  381.910902
# 15     375.249876  410.488545
# 16     378.186435  409.020270
# 17     369.376760  410.488539
# 18     363.503648  409.020261
# 19     340.011201  433.980984
# 20     344.416038  375.249873
# 21     359.098816  414.893373
# 22     363.503648  414.893375
# 23     351.757426  417.829930
# 24     357.630538  422.234763
# 25     354.693983  435.449265
# 26     341.479481  444.258929
# 27     317.386876  454.629304
# 28     330.303810  412.649262
# 29     360.852841  480.625275
# ...           ...         ...
# 91319  414.147146  432.881849
# 91320  437.706257  461.458839
# 91321  440.675331  464.427912
# 91322  255.579243  286.543248
# 91323  249.058291  278.676034
# 91324  238.172178  390.087404
# 91325  231.735091  363.051642
# 91326  256.196017  328.291379
# 91327  390.087403  401.674157
# 91328  245.896680  266.495353
# 91329  248.303053  273.258132
# 91330  249.550809  275.753642
# 91331  233.330005  264.523855
# 91332  256.222506  297.359145
# 91333  314.109557  328.433770
# 91334  327.161106  413.256135
# 91335  283.489715  322.170090
# 91336  287.232977  362.098219
# 91337  285.343708  337.224383
# 91338  278.570306  351.957106
# 91339  274.077236  356.450176
# 91340  290.551825  347.464036
# 91341  284.561065  351.957106
# 91342  272.579547  378.915523
# 91343  251.611888  402.878559
# 91344  317.179074  384.557793
# 91345  327.161106  359.602709
# 91346  329.656614  384.557793
# 91347  345.877417  385.805546
# 91348  334.647630  378.319022
#
# [91349 rows x 7 columns]

# %%
output.to_csv(dataset_filename + '.output.csv')
